# %%
#Import Libraries

from textblob import TextBlob
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import nltk
import nltk
import re
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from collections import Counter
sns.set()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\neuma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\neuma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\neuma\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
#Import txt file

file_path = r"C:\Users\neuma\OneDrive\Desktop\Specialisation\20th-century\key_events_20th_century.txt"

with open(file_path, 'r', encoding='utf-8', errors='ignore') as file:
    data = file.read().replace('\n', ' ')

# %% [markdown]
# # Tokenisation

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\neuma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk import FreqDist, word_tokenize
import string

# %%
from nltk.tokenize import sent_tokenize
tokenized_sent = sent_tokenize(data)
print(tokenized_sent)
# Out:
# ["  Key events of the 20th century - Wikipedia                           Close November 5th, 10:23 pm: “Wikipedia still can't be sold.” - An important update for readers in Germany.", 'Today is the day.', "We're sorry to interrupt, but it's Wednesday, November 5th, and this message will be up for only a few hours.", "We ask you to reflect on the number of times you visited Wikipedia in the past year and if you're able to give €5 back.", 'Our fundraising appeal is displayed over 6 million times a day, but currently only 89,237 people have donated.', 'In the age of AI, access to verifiable facts is crucial.', 'Wikipedia is at the heart of online information, powering everything from your personal searches to emerging AI technologies.', 'Your gift strengthens the knowledge of today and tomorrow.', 'Just 1% of our readers donate, so if you have given in the past and Wikipedia still provides you with €5 worth of knowledge, kindly donate today.', "If you are undecided, remember that any co
# ...

# %%
#word tokenisation

from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(data)
print(tokenized_word)
# Out:
# ['Key', 'events', 'of', 'the', '20th', 'century', '-', 'Wikipedia', 'Close', 'November', '5th', ',', '10:23', 'pm', ':', '“', 'Wikipedia', 'still', 'ca', "n't", 'be', 'sold.', '”', '-', 'An', 'important', 'update', 'for', 'readers', 'in', 'Germany', '.', 'Today', 'is', 'the', 'day', '.', 'We', "'re", 'sorry', 'to', 'interrupt', ',', 'but', 'it', "'s", 'Wednesday', ',', 'November', '5th', ',', 'and', 'this', 'message', 'will', 'be', 'up', 'for', 'only', 'a', 'few', 'hours', '.', 'We', 'ask', 'you', 'to', 'reflect', 'on', 'the', 'number', 'of', 'times', 'you', 'visited', 'Wikipedia', 'in', 'the', 'past', 'year', 'and', 'if', 'you', "'re", 'able', 'to', 'give', '€5', 'back', '.', 'Our', 'fundraising', 'appeal', 'is', 'displayed', 'over', '6', 'million', 'times', 'a', 'day', ',', 'but', 'currently', 'only', '89,237', 'people', 'have', 'donated', '.', 'In', 'the', 'age', 'of', 'AI', ',', 'access', 'to', 'verifiable', 'facts', 'is', 'crucial', '.', 'Wikipedia', 'is', 'at', 'the', 'heart', 
# ...

# %%
#frequency check-up

from nltk.probability import FreqDist
dist_words = FreqDist(tokenized_word)
print(dist_words)
# Out:
# <FreqDist with 5159 samples and 23341 outcomes>

# %%
dist_words.most_common(50)
# Out:
# [('.', 1649),
#  ('the', 1163),
#  (',', 1020),
#  ('of', 650),
#  ('and', 437),
#  ('to', 361),
#  ('The', 331),
#  ('in', 324),
#  ('[', 309),
#  (']', 309),
#  ("''", 277),
#  ('^', 274),
#  ('``', 273),
#  ('(', 260),
#  (')', 260),
#  ('2018', 244),
#  ('December', 225),
#  ('a', 209),
#  ('Retrieved', 209),
#  (':', 194),
#  ('was', 137),
#  ('on', 125),
#  ('War', 125),
#  ('as', 98),
#  ('war', 81),
#  ('by', 79),
#  ("'s", 77),
#  ('World', 77),
#  ('for', 75),
#  ('with', 72),
#  ('that', 66),
#  ('from', 64),
#  ('were', 64),
#  ('which', 56),
#  ('Soviet', 56),
#  ('20', 54),
#  ('it', 51),
#  ('Hitler', 51),
#  ('at', 49),
#  ('12', 49),
#  ('had', 45),
#  ('Germany', 44),
#  ('–', 44),
#  ('History', 42),
#  ('13', 41),
#  ('world', 40),
#  ('first', 40),
#  ('ISBN', 40),
#  ('century', 39),
#  ('its', 39)]

# %%
dist_words.most_common(100)
# Out:
# [('.', 1649),
#  ('the', 1163),
#  (',', 1020),
#  ('of', 650),
#  ('and', 437),
#  ('to', 361),
#  ('The', 331),
#  ('in', 324),
#  ('[', 309),
#  (']', 309),
#  ("''", 277),
#  ('^', 274),
#  ('``', 273),
#  ('(', 260),
#  (')', 260),
#  ('2018', 244),
#  ('December', 225),
#  ('a', 209),
#  ('Retrieved', 209),
#  (':', 194),
#  ('was', 137),
#  ('on', 125),
#  ('War', 125),
#  ('as', 98),
#  ('war', 81),
#  ('by', 79),
#  ("'s", 77),
#  ('World', 77),
#  ('for', 75),
#  ('with', 72),
#  ('that', 66),
#  ('from', 64),
#  ('were', 64),
#  ('which', 56),
#  ('Soviet', 56),
#  ('20', 54),
#  ('it', 51),
#  ('Hitler', 51),
#  ('at', 49),
#  ('12', 49),
#  ('had', 45),
#  ('Germany', 44),
#  ('–', 44),
#  ('History', 42),
#  ('13', 41),
#  ('world', 40),
#  ('first', 40),
#  ('ISBN', 40),
#  ('century', 39),
#  ('its', 39),
#  ('11', 39),
#  ('In', 38),
#  ('would', 38),
#  ('is', 36),
#  ('but', 34),
#  ('edit', 34),
#  ('Japan', 33),
#  ('also', 32),
#  ('II', 32),
# ...

# %%
#Frequency Distribution Plot

plt.figure(figsize=(8, 3))
dist_words.plot(10,cumulative = False)
plt.show()

# %%
#Filtering

# %%
filtered_words = []
for word in tokenized_word:
    if word not in stop_words:
        filtered_words.append(word)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 filtered_words = []
#       2 for word in tokenized_word:
# ----> 3     if word not in stop_words:
#       4         filtered_words.append(word)
#
# NameError: name 'stop_words' is not defined

# %%
#Exercise notebook provided example code does not work properly

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\neuma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\neuma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stop_words=set(stopwords.words('english'))

# %%
tokens=word_tokenize(data.lower())

# %%
filtered_words = [
    word for word in tokens 
    if word.isalnum() and word not in stop_words
]

# %%
dist_words_filter = FreqDist(filtered_words)
print (dist_words_filter)
# Out:
# <FreqDist with 4069 samples and 11782 outcomes>

# %%
plt.figure(figsize=(8, 3))
dist_words_filter.plot(30,cumulative = False)
plt.show()

# %%
new_stopwords = ["And", "Then", 'n', 't', 's', 'The','also','isbn','edit','ii','the','of','in','to','and','then','a','for','from']

# %%
filtered_words_2 = [
    word for word in tokens 
    if word.isalnum() and word not in new_stopwords
]

# %%
dist_words_filter_2 = FreqDist(filtered_words_2)
print (dist_words_filter)
# Out:
# <FreqDist with 4069 samples and 11782 outcomes>

# %%
plt.figure(figsize=(8, 3))
dist_words_filter_2.plot(30,cumulative = False)
plt.show()

# %%
# %%time
text = TextBlob(" ".join(filtered_words))
# Out:
# CPU times: total: 0 ns
# Wall time: 1.47 ms

# %%
#Tags

tags_list = text.tags
tags_list
# Out:
# [('key', 'JJ'),
#  ('events', 'NNS'),
#  ('20th', 'JJ'),
#  ('century', 'NN'),
#  ('wikipedia', 'NN'),
#  ('close', 'JJ'),
#  ('november', 'JJ'),
#  ('5th', 'CD'),
#  ('pm', 'NN'),
#  ('wikipedia', 'NN'),
#  ('still', 'RB'),
#  ('ca', 'MD'),
#  ('important', 'JJ'),
#  ('update', 'JJ'),
#  ('readers', 'NNS'),
#  ('germany', 'VBP'),
#  ('today', 'NN'),
#  ('day', 'NN'),
#  ('sorry', 'VB'),
#  ('interrupt', 'JJ'),
#  ('wednesday', 'JJ'),
#  ('5th', 'CD'),
#  ('message', 'NN'),
#  ('hours', 'NNS'),
#  ('ask', 'VBP'),
#  ('reflect', 'JJ'),
#  ('number', 'NN'),
#  ('times', 'NNS'),
#  ('visited', 'JJ'),
#  ('wikipedia', 'NN'),
#  ('past', 'IN'),
#  ('year', 'NN'),
#  ('able', 'JJ'),
#  ('give', 'VBP'),
#  ('back', 'RP'),
#  ('fundraising', 'VBG'),
#  ('appeal', 'NN'),
#  ('displayed', 'VBD'),
#  ('6', 'CD'),
#  ('million', 'CD'),
#  ('times', 'NNS'),
#  ('day', 'NN'),
#  ('currently', 'RB'),
#  ('people', 'NNS'),
#  ('donated', 'VBD'),
#  ('age', 'NN'),
#  ('ai', 'JJ'),
# ...

# %%
df_text = pd.DataFrame(tags_list)
df_text.columns = ['Words', "Word type"]

# %%
df_text
# Out:
#            Words Word type
# 0            key        JJ
# 1         events       NNS
# 2           20th        JJ
# 3        century        NN
# 4      wikipedia        NN
# ...          ...       ...
# 11772    century        NN
# 11773          2        CD
# 11774  languages       NNS
# 11775        add       VBP
# 11776      topic        NN
#
# [11777 rows x 2 columns]

# %%
df_text = pd.DataFrame(tags_list)
df_text.columns = [ 'Words', "Word type"]
df_t=df_text.groupby('Word type').count().reset_index()
top20=df_t.nlargest(20, 'Words')

# %%
df_t.head()
# Out:
#   Word type  Words
# 0        CC      7
# 1        CD   1581
# 2        DT      8
# 3        FW     20
# 4        IN    165

# %%
plt.figure(figsize = (10, 5))
with sns.dark_palette("xkcd:blue", 20):
      sns.barplot(x = "Words", y = "Word type",
     saturation = 0.9, data = top20).set_title("20th_century - top 20 word types used")

# %%
#most used verbs

df = df_text[(df_text['Word type'] == "VB")  | (df_text['Word type'] == "VBD")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top15 = y.nlargest(15, 'Occurences')

# %%
plt.figure(figsize=(15, 5))
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x="Word", y="Occurences",
    saturation=0.9, data = top15).set_title("20th_century - most frequently used verbs")

# %%
#most used nouns

df = df_text[(df_text['Word type'] == "NN")  | (df_text['Word type'] == "NNS")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top15 = y.nlargest(15, 'Occurences')

# %%
plt.figure(figsize=(15, 5))
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x="Word", y="Occurences",
    saturation=0.9, data = top15).set_title("20th_century - most frequently used nouns")

# %%
#most used adjectives

df = df_text[(df_text['Word type'] == "JJ")  | (df_text['Word type'] == "JJS")  | (df_text['Word type'] == "JJR")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top15 = y.nlargest(15, 'Occurences')

# %%
plt.figure(figsize=(15, 5))
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x="Word", y="Occurences",
    saturation=0.9, data = top15).set_title("20th_century - most frequently used adjectives")

# %% [markdown]
# # Notes
#
# Even for one without historic knowledge, these charts tell quite a coherent story about the historical tone in the 20th century. Which was marked by terrific global conflicts and wars.

# %%
#country frequencies

# %%
# !pip install pycountry

# %%
#import library

import pycountry

# %%
#create country list

countries = [country.name for country in pycountry.countries]

# %%
print(countries)
# Out:
# ['Aruba', 'Afghanistan', 'Angola', 'Anguilla', 'Åland Islands', 'Albania', 'Andorra', 'United Arab Emirates', 'Argentina', 'Armenia', 'American Samoa', 'Antarctica', 'French Southern Territories', 'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Bonaire, Sint Eustatius and Saba', 'Burkina Faso', 'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas', 'Bosnia and Herzegovina', 'Saint Barthélemy', 'Belarus', 'Belize', 'Bermuda', 'Bolivia, Plurinational State of', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan', 'Bouvet Island', 'Botswana', 'Central African Republic', 'Canada', 'Cocos (Keeling) Islands', 'Switzerland', 'Chile', 'China', "Côte d'Ivoire", 'Cameroon', 'Congo, The Democratic Republic of the', 'Congo', 'Cook Islands', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica', 'Cuba', 'Curaçao', 'Christmas Island', 'Cayman Islands', 'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark', 'Dominican Republic', 'Algeria', 'Ecuador', 'E
# ...

# %%
df = pd.DataFrame(countries, columns =  ["Country"])

# %%
df.head(25)
# Out:
#                              Country
# 0                              Aruba
# 1                        Afghanistan
# 2                             Angola
# 3                           Anguilla
# 4                      Åland Islands
# 5                            Albania
# 6                            Andorra
# 7               United Arab Emirates
# 8                          Argentina
# 9                            Armenia
# 10                    American Samoa
# 11                        Antarctica
# 12       French Southern Territories
# 13               Antigua and Barbuda
# 14                         Australia
# 15                           Austria
# 16                        Azerbaijan
# 17                           Burundi
# 18                           Belgium
# 19                             Benin
# 20  Bonaire, Sint Eustatius and Saba
# 21                      Burkina Faso
# 22                        Bangladesh
# 23                          Bulgaria
# ...

# %%
text_clean = data.lower()

# %%
for country in countries:
    count = text_clean.count(country.lower())
    if count > 0: 
        country_mentions.append({'Country': country, 'Mentions': count})

# %%
df_countries = pd.DataFrame(country_mentions).sort_values(by='Mentions', ascending=False)

# %%
df_countries.reset_index(drop=True, inplace=True)

# %%
df_countries.head(25)
# Out:
#           Country  Mentions
# 0           Japan        69
# 1           Japan        69
# 2         Germany        45
# 3         Germany        45
# 4   United States        23
# 5   United States        23
# 6          Russia        18
# 7          Russia        18
# 8          France        17
# 9          France        17
# 10        Vietnam        16
# 11        Vietnam        16
# 12          Italy        14
# 13          Italy        14
# 14         Poland        13
# 15         Poland        13
# 16          India        12
# 17          India        12
# 18          China        12
# 19          China        12
# 20           Cuba         9
# 21           Cuba         9
# 22    North Korea         6
# 23      Australia         6
# 24      Australia         6

# %%
df_countries.to_csv('20th_century_countries.csv')

# %%
#plot

plt.figure(figsize=(15, 5))
sns.barplot(x='Mentions', y='Country', data=df_countries.head(20), palette='Blues_r')
plt.title('Top 20 Countries by Mention on the Events of the 20th Century Wikipedia Page')
plt.xlabel('Mentions')
plt.ylabel('Country')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\neuma\AppData\Local\Temp\ipykernel_19728\2883681147.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Mentions', y='Country', data=df_countries.head(20), palette='Blues_r')

# %% [markdown]
# # Notes
#
# The website's perspective of the 20th century is centered on big global powers and wars, rather than cultural or economic events. The Top 5 countries by mention are :Japan, Germany, the US, France and Italy.
#
# Europe: Germany, France, Italy, Poland, Austria, Finland, Slovakia, Lithuania, Norway
# Both world wars were mostly fought on european grounds , therefor a higher frequency of european countries from a western standpoint is apparent.
#
# North America: The United States ranks among the top 3, reflecting its strong involvement throughout the century. The US alone spend 25 years of the 20th century involved and participating in wars ( war on vietnam, part of the allied forces in the second world war, korean war, attacks on cuba...).
#
# Asia: Japan and China are in the top ten, both were key players in WWII and later Cold War developments. Additionally the manchuria war (Japan against china).

# %%
# Countries with list

# %%
countries = [
    "Afghanistan", "Albania", "Algeria", "Andorra", "Angola", "Argentina", "Armenia", "Australia",
    "Austria", "Azerbaijan", "Bahamas", "Bahrain", "Bangladesh", "Barbados", "Belarus", "Belgium",
    "Belize", "Benin", "Bhutan", "Bolivia", "Bosnia", "Botswana", "Brazil", "Brunei", "Bulgaria",
    "Burkina Faso", "Burundi", "Cambodia", "Cameroon", "Canada", "Cape Verde", "Chad", "Chile",
    "China", "Colombia", "Comoros", "Costa Rica", "Croatia", "Cuba", "Cyprus", "Czech Republic",
    "Denmark", "Djibouti", "Dominica", "Dominican Republic", "Ecuador", "Egypt", "El Salvador",
    "Equatorial Guinea", "Eritrea", "Estonia", "Eswatini", "Ethiopia", "Fiji", "Finland", "France",
    "Gabon", "Gambia", "Georgia", "Germany", "Ghana", "Greece", "Grenada", "Guatemala", "Guinea",
    "Guyana", "Haiti", "Honduras", "Hungary", "Iceland", "India", "Indonesia", "Iran", "Iraq",
    "Ireland", "Israel", "Italy", "Jamaica", "Japan", "Jordan", "Kazakhstan", "Kenya", "Kiribati",
    "Kuwait", "Kyrgyzstan", "Laos", "Latvia", "Lebanon", "Lesotho", "Liberia", "Libya",
    "Liechtenstein", "Lithuania", "Luxembourg", "Madagascar", "Malawi", "Malaysia", "Maldives",
    "Mali", "Malta", "Mauritania", "Mauritius", "Mexico", "Micronesia", "Moldova", "Monaco",
    "Mongolia", "Montenegro", "Morocco", "Mozambique", "Myanmar", "Namibia", "Nauru", "Nepal",
    "Netherlands", "New Zealand", "Nicaragua", "Niger", "Nigeria", "North Korea", "North Macedonia",
    "Norway", "Oman", "Pakistan", "Palau", "Panama", "Papua New Guinea", "Paraguay", "Peru",
    "Philippines", "Poland", "Portugal", "Qatar", "Romania", "Russia", "Rwanda", "Saint Lucia",
    "Samoa", "San Marino", "Saudi Arabia", "Senegal", "Serbia", "Seychelles", "Sierra Leone",
    "Singapore", "Slovakia", "Slovenia", "Somalia", "South Africa", "South Korea", "Spain",
    "Sri Lanka", "Sudan", "Suriname", "Sweden", "Switzerland", "Syria", "Taiwan", "Tajikistan",
    "Tanzania", "Thailand", "Togo", "Tonga", "Trinidad", "Tunisia", "Turkey", "Turkmenistan",
    "Uganda", "Ukraine", "United Arab Emirates", "United Kingdom", "United States", "Uruguay",
    "Uzbekistan", "Vanuatu", "Vatican", "Venezuela", "Vietnam", "Yemen", "Zambia", "Zimbabwe"
]

# %%
listToStr = ' '.join([str(elem) for elem in dist_words_filter_2])
 
print(listToStr)
# Out:
# 2018 december retrieved war was on world as by with history that it were which soviet this at new 20 first hitler 12 century had germany would its 13 is battle nuclear 11 after an but states japan end japanese germans 15 union be their not german united september only his issn became europe july august weapons all they many into main nations during space against 18 27 june people one other army april 20th over or most africa attack may you between holocaust american october computer our two stalin second north bbc wikipedia allied countries allies 17 britain wars what british forces however invasion november we have us free cold 2 great could he nazi how january 1 more berlin such economic france 7 time jews east later been internet archived these international government about february 1945 press day made operation 5 led military crisis south when did 16 air national york 6 i under rise pacific 3 general article state some out italy began 2017 original up times million now use why b
# ...

# %%
all_counts = Counter(re.sub(r'\W+', ' ', listToStr).split())

# %%
all_counts
# Out:
# Counter({'2018': 1,
#          'december': 1,
#          'retrieved': 1,
#          'war': 1,
#          'was': 1,
#          'on': 1,
#          'world': 1,
#          'as': 1,
#          'by': 1,
#          'with': 1,
#          'history': 1,
#          'that': 1,
#          'it': 1,
#          'were': 1,
#          'which': 1,
#          'soviet': 1,
#          'this': 1,
#          'at': 1,
#          'new': 1,
#          '20': 1,
#          'first': 1,
#          'hitler': 1,
#          '12': 1,
#          'century': 1,
#          'had': 1,
#          'germany': 1,
#          'would': 1,
#          'its': 1,
#          '13': 1,
#          'is': 1,
#          'battle': 1,
#          'nuclear': 1,
#          '11': 1,
#          'after': 1,
#          'an': 1,
#          'but': 1,
#          'states': 1,
#          'japan': 1,
#          'end': 1,
#          'japanese': 1,
#          'germans': 1,
#          '15': 1,
#          'union': 1,
#          'be': 1,
# ...

# %%
text_clean = data.lower()

# %%
country_mentions = []

# %%
for country in countries:
    count = text_clean.count(country.lower())
    
    if count > 0: 
        country_mentions.append({"Country": country, "Mentions": count})

# %%
df_country_mentions = pd.DataFrame(country_mentions)

# %%
df_country_mentions
# Out:
#            Country  Mentions
# 0      Afghanistan         1
# 1          Albania         2
# 2          Algeria         1
# 3           Angola         1
# 4        Australia         6
# ..             ...       ...
# 66        Thailand         1
# 67         Ukraine         2
# 68  United Kingdom         2
# 69   United States        23
# 70         Vietnam        16
#
# [71 rows x 2 columns]

# %%
df = df_country_mentions.transpose().reset_index()

# %%
df.dtypes
# Out:
# index    object
# 0        object
# 1        object
# 2        object
# 3        object
#           ...
# 66       object
# 67       object
# 68       object
# 69       object
# 70       object
# Length: 72, dtype: object

# %%
df
# Out:
#       index            0        1        2       3          4        5  \
# 0   Country  Afghanistan  Albania  Algeria  Angola  Australia  Austria
# 1  Mentions            1        2        1       1          6        5
#
#             6        7        8  ...            61           62     63     64  \
# 0  Bangladesh  Belarus  Belgium  ...  South Africa  South Korea  Spain  Sudan
# 1           2        1        2  ...             3            3      1      1
#
#        65        66       67              68             69       70
# 0  Sweden  Thailand  Ukraine  United Kingdom  United States  Vietnam
# 1       1         1        2               2             23       16
#
# [2 rows x 72 columns]

# %%
plt.figure(figsize=(10, 15))
with sns.dark_palette("#79C", 27):
    sns.barplot(x = "Mentions", y = "Country",
    saturation=0.9, data = df_country_mentions.sort_values("Mentions", ascending = False)).set_title("20th Century Wikipedia - most frequently mentioned countries")
