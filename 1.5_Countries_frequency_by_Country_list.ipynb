# %%
#Import Libraries

from textblob import TextBlob
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import nltk
import nltk
import re
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from collections import Counter
sns.set()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\neuma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\neuma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\neuma\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
#Import txt file

file_path = r"C:\Users\neuma\OneDrive\Desktop\Specialisation\20th-century\key_events_20th_century_cleaned.txt"

with open(file_path, 'r', encoding='utf-8', errors='ignore') as file:
    data = file.read().replace('\n', ' ')

# %% [markdown]
# # Tokenisation

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\neuma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk import FreqDist, word_tokenize
import string

# %%
from nltk.tokenize import sent_tokenize
tokenized_sent = sent_tokenize(data)
print(tokenized_sent)
# Out:
# ['  Key events of the 20th century - Wikipedia  Close November 5th, 10:23 pm: "Wikipedia still can\'t be sold."', '- An important update for readers in Germany.', 'Today is the day.', "We're sorry to interrupt, but it's Wednesday, November 5th, and this message will be up for only a few hours.", "We ask you to reflect on the number of times you visited Wikipedia in the past year and if you're able to give €5 back.", 'Our fundraising appeal is displayed over 6 million times a day, but currently only 89,237 people have donated.', 'In the age of AI, access to verifiable facts is crucial.', 'Wikipedia is at the heart of online information, powering everything from your personal searches to emerging AI technologies.', 'Your gift strengthens the knowledge of today and tomorrow.', 'Just 1% of our readers donate, so if you have given in the past and Wikipedia still provides you with €5 worth of knowledge, kindly donate today.', "If you are undecided, remember that any contribution helps, whether it's €5 or €25.", 'Thank\xa0you.', '€2.5MDonation target: €8.0M€2.5MI will donate:one-timemonthlyquarterlyyearlyHow often would you like to donate?Amount:€5€10€20€25€50€100How much would you like to donate?Using:PayPal LogoVisa LogoMastercard LogoHow would you like to pay your donation?Proceed with the donation Please make it €0 yearly!Every year we are dependent on the support of people like you.', "Yearly donations help sustainably and enable long term development.No risks attached, you can tell us to stop at any time.No, I'll donate €0 one time.Yes, I'll donate €0 each year.Donation account: Wikimedia e. V.BIC: BFSWDE33XXXIBAN: DE09 3702 0500 0003 2873 00 I've already donatedWhere does my donation go?CloseWhere does my donation go?It is for a Wikipedia that is always reliable in terms of organizational and technical aspects, now and in the future.", 'For free access to encyclopedic, trustworthy knowledge at all times and wherever you are.', 'It is also for you - and for all other people around the world.Technology and IT work in Germany In order for our volunteers to always be working under optimal conditions on Wikipedia and its fellow projects, they need the best technical infrastructure.', 'Furthermore, that infrastructure needs to be easy to use.', "That's why further development of the technology behind the projects represents our greatest field of endeavor, both in terms of staffing and spending.", 'Our commitment in this area has made us a technical pioneer in the free-knowledge movement.Supporting the volunteers Volunteers in our projects receive no money, but we make a large investment in supporting them.', "Wikimedia steps in where volunteer dedication alone isn't enough: We organize events, purchase specialist literature, enable collaborations and supply photo equipment for photos on Wikipedia.", 'We also provide funding for local spaces in various cities across Germany where volunteers can do their work.', "In short: We're there for them whenever they need us.Strengthening Wikipedia projects across the world Wikipedia is a global project, with more than 300 language versions.", 'If we are to secure and further develop these international activities, it demands of us a consistent financial commitment.', 'Having performant, data-minimizing, secure technology is crucial.', 'Wikimedia independently runs seven server farms across the globe.', 'Beyond that we assist with grants, legal assistance and other measures in building thriving communities of volunteers all over the world.Operational costs Our colleagues in the Berlin office make sure that our organizational and financial processes work reliably.', 'They take care of matters such as processing incoming donations and handling the many and varied concerns of our supporters.', "They also respond to all the requests regarding our projects and see to raising their public profiles.And even that's not all: we work closely with cultural institutions, act as a political point of contact ...

# %%
#word tokenisation

from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(data)
print(tokenized_word)
# Out:
# ['Key', 'events', 'of', 'the', '20th', 'century', '-', 'Wikipedia', 'Close', 'November', '5th', ',', '10:23', 'pm', ':', '``', 'Wikipedia', 'still', 'ca', "n't", 'be', 'sold', '.', "''", '-', 'An', 'important', 'update', 'for', 'readers', 'in', 'Germany', '.', 'Today', 'is', 'the', 'day', '.', 'We', "'re", 'sorry', 'to', 'interrupt', ',', 'but', 'it', "'s", 'Wednesday', ',', 'November', '5th', ',', 'and', 'this', 'message', 'will', 'be', 'up', 'for', 'only', 'a', 'few', 'hours', '.', 'We', 'ask', 'you', 'to', 'reflect', 'on', 'the', 'number', 'of', 'times', 'you', 'visited', 'Wikipedia', 'in', 'the', 'past', 'year', 'and', 'if', 'you', "'re", 'able', 'to', 'give', '€5', 'back', '.', 'Our', 'fundraising', 'appeal', 'is', 'displayed', 'over', '6', 'million', 'times', 'a', 'day', ',', 'but', 'currently', 'only', '89,237', 'people', 'have', 'donated', '.', 'In', 'the', 'age', 'of', 'AI', ',', 'access', 'to', 'verifiable', 'facts', 'is', 'crucial', '.', 'Wikipedia', 'is', 'at', 'the', 'heart', 'of', 'online', 'information', ',', 'powering', 'everything', 'from', 'your', 'personal', 'searches', 'to', 'emerging', 'AI', 'technologies', '.', 'Your', 'gift', 'strengthens', 'the', 'knowledge', 'of', 'today', 'and', 'tomorrow', '.', 'Just', '1', '%', 'of', 'our', 'readers', 'donate', ',', 'so', 'if', 'you', 'have', 'given', 'in', 'the', 'past', 'and', 'Wikipedia', 'still', 'provides', 'you', 'with', '€5', 'worth', 'of', 'knowledge', ',', 'kindly', 'donate', 'today', '.', 'If', 'you', 'are', 'undecided', ',', 'remember', 'that', 'any', 'contribution', 'helps', ',', 'whether', 'it', "'s", '€5', 'or', '€25', '.', 'Thank', 'you', '.', '€2.5MDonation', 'target', ':', '€8.0M€2.5MI', 'will', 'donate', ':', 'one-timemonthlyquarterlyyearlyHow', 'often', 'would', 'you', 'like', 'to', 'donate', '?', 'Amount', ':', '€5€10€20€25€50€100How', 'much', 'would', 'you', 'like', 'to', 'donate', '?', 'Using', ':', 'PayPal', 'LogoVisa', 'LogoMastercard', 'LogoHow', 'would', 'you', 'like', 'to', 'pay', 'your', 'donation', '?', 'Proceed', 'with', 'the', 'donation', 'Please', 'make', 'it', '€0', 'yearly', '!', 'Every', 'year', 'we', 'are', 'dependent', 'on', 'the', 'support', 'of', 'people', 'like', 'you', '.', 'Yearly', 'donations', 'help', 'sustainably', 'and', 'enable', 'long', 'term', 'development.No', 'risks', 'attached', ',', 'you', 'can', 'tell', 'us', 'to', 'stop', 'at', 'any', 'time.No', ',', 'I', "'ll", 'donate', '€0', 'one', 'time.Yes', ',', 'I', "'ll", 'donate', '€0', 'each', 'year.Donation', 'account', ':', 'Wikimedia', 'e.', 'V.BIC', ':', 'BFSWDE33XXXIBAN', ':', 'DE09', '3702', '0500', '0003', '2873', '00', 'I', "'ve", 'already', 'donatedWhere', 'does', 'my', 'donation', 'go', '?', 'CloseWhere', 'does', 'my', 'donation', 'go', '?', 'It', 'is', 'for', 'a', 'Wikipedia', 'that', 'is', 'always', 'reliable', 'in', 'terms', 'of', 'organizational', 'and', 'technical', 'aspects', ',', 'now', 'and', 'in', 'the', 'future', '.', 'For', 'free', 'access', 'to', 'encyclopedic', ',', 'trustworthy', 'knowledge', 'at', 'all', 'times', 'and', 'wherever', 'you', 'are', '.', 'It', 'is', 'also', 'for', 'you', '-', 'and', 'for', 'all', 'other', 'people', 'around', 'the', 'world.Technology', 'and', 'IT', 'work', 'in', 'Germany', 'In', 'order', 'for', 'our', 'volunteers', 'to', 'always', 'be', 'working', 'under', 'optimal', 'conditions', 'on', 'Wikipedia', 'and', 'its', 'fellow', 'projects', ',', 'they', 'need', 'the', 'best', 'technical', 'infrastructure', '.', 'Furthermore', ',', 'that', 'infrastructure', 'needs', 'to', 'be', 'easy', 'to', 'use', '.', 'That', "'s", 'why', 'further', 'development', 'of', 'the', 'technology', 'behind', 'the', 'projects', 'represents', 'our', 'greatest', 'field', 'of', 'endeavor', ',', 'both', 'in', 'terms', 'of', 'staffing', 'and', 'spending', '.', 'Our', 'commitment', 'in', 'this', 'area', 'has', 'made', 'us', 'a', 'technical', 'pioneer', 'in', 'the', 'free-knowledge', 'movement.Supporting', 'the', 'volunteers', 'Volunteers', 'in', 'our', ...

# %%
#frequency check-up

from nltk.probability import FreqDist
dist_words = FreqDist(tokenized_word)
print(dist_words)
# Out:
# <FreqDist with 4949 samples and 22500 outcomes>

# %%
dist_words.most_common(50)
# Out:
# [('.', 1635),
#  ('the', 1163),
#  (',', 1020),
#  ('of', 650),
#  ('and', 437),
#  ('to', 361),
#  ('The', 331),
#  ('in', 324),
#  ("''", 279),
#  ('``', 275),
#  ('^', 274),
#  ('(', 260),
#  (')', 260),
#  ('2018', 244),
#  ('December', 225),
#  ('a', 209),
#  ('Retrieved', 209),
#  (':', 194),
#  ('was', 137),
#  ('on', 125),
#  ('War', 125),
#  ('as', 98),
#  ('war', 81),
#  ("'s", 79),
#  ('by', 79),
#  ('World', 77),
#  ('for', 75),
#  ('with', 72),
#  ('that', 66),
#  ('from', 64),
#  ('were', 64),
#  ('which', 56),
#  ('Soviet', 56),
#  ('20', 53),
#  ('it', 51),
#  ('Hitler', 51),
#  ('at', 49),
#  ('-', 48),
#  ('12', 48),
#  ('had', 45),
#  ('Germany', 44),
#  ('History', 42),
#  ('world', 40),
#  ('first', 40),
#  ('13', 40),
#  ('ISBN', 40),
#  ('century', 39),
#  ('its', 39),
#  ('In', 38),
#  ('would', 38)]

# %%
dist_words.most_common(100)
# Out:
# [('.', 1635),
#  ('the', 1163),
#  (',', 1020),
#  ('of', 650),
#  ('and', 437),
#  ('to', 361),
#  ('The', 331),
#  ('in', 324),
#  ("''", 279),
#  ('``', 275),
#  ('^', 274),
#  ('(', 260),
#  (')', 260),
#  ('2018', 244),
#  ('December', 225),
#  ('a', 209),
#  ('Retrieved', 209),
#  (':', 194),
#  ('was', 137),
#  ('on', 125),
#  ('War', 125),
#  ('as', 98),
#  ('war', 81),
#  ("'s", 79),
#  ('by', 79),
#  ('World', 77),
#  ('for', 75),
#  ('with', 72),
#  ('that', 66),
#  ('from', 64),
#  ('were', 64),
#  ('which', 56),
#  ('Soviet', 56),
#  ('20', 53),
#  ('it', 51),
#  ('Hitler', 51),
#  ('at', 49),
#  ('-', 48),
#  ('12', 48),
#  ('had', 45),
#  ('Germany', 44),
#  ('History', 42),
#  ('world', 40),
#  ('first', 40),
#  ('13', 40),
#  ('ISBN', 40),
#  ('century', 39),
#  ('its', 39),
#  ('In', 38),
#  ('would', 38),
#  ('11', 38),
#  ('is', 36),
#  ('but', 34),
#  ('[', 34),
#  ('edit', 34),
#  (']', 34),
#  ('Japan', 33),
#  ('also', 32),
#  ('II', 32),
#  ('Japanese', 32),
#  ('Germans', 32),
#  ('this', 31),
#  ('an', 31),
#  ('German', 31),
#  ('New', 31),
#  ('Union', 31),
#  ('United', 31),
#  ('September', 31),
#  ('15', 31),
#  ('only', 30),
#  (';', 30),
#  ('ISSN', 30),
#  ('be', 29),
#  ('their', 29),
#  ('not', 29),
#  ('became', 29),
#  ('Europe', 28),
#  ('July', 28),
#  ('August', 28),
#  ('|', 28),
#  ('end', 27),
#  ('his', 27),
#  ('all', 26),
#  ('into', 26),
#  ('nuclear', 26),
#  ('States', 25),
#  ('June', 25),
#  ('Battle', 25),
#  ('after', 24),
#  ('This', 24),
#  ('April', 24),
#  ('18', 24),
#  ('27', 24),
#  ('20th', 23),
#  ('or', 23),
#  ('other', 23),
#  ('new', 23),
#  ('Africa', 23),
#  ('against', 23),
#  ('attack', 23)]

# %%
#Frequency Distribution Plot

plt.figure(figsize=(8, 3))
dist_words.plot(10,cumulative = False)
plt.show()

# %%
#Filtering

# %%
stop_words = set(stopwords.words('english'))

# %%
filtered_words = []
for word in tokenized_word:
    if word not in stop_words:
        filtered_words.append(word)

# %%
#Exercise notebook provided example code does not work properly

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\neuma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\neuma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stop_words=set(stopwords.words('english'))

# %%
tokens=word_tokenize(data.lower())

# %%
filtered_words = [
    word for word in tokens 
    if word.isalnum() and word not in stop_words
]

# %%
dist_words_filter = FreqDist(filtered_words)
print (dist_words_filter)
# Out:
# <FreqDist with 3853 samples and 11493 outcomes>

# %%
plt.figure(figsize=(8, 3))
dist_words_filter.plot(30,cumulative = False)
plt.show()

# %%
new_stopwords = ["And", "Then", 'n', 't', 's', 'The','also','isbn','edit','ii','the','of','in','to','and','then','a','for','from']

# %%
filtered_words_2 = [
    word for word in tokens 
    if word.isalnum() and word not in new_stopwords
]

# %%
dist_words_filter_2 = FreqDist(filtered_words_2)
print (dist_words_filter)
# Out:
# <FreqDist with 3853 samples and 11493 outcomes>

# %%
plt.figure(figsize=(8, 3))
dist_words_filter_2.plot(30,cumulative = False)
plt.show()

# %%
# %%time
text = TextBlob(" ".join(filtered_words))
# Out:
# CPU times: total: 0 ns
# Wall time: 2.51 ms

# %%
#Tags

tags_list = text.tags
tags_list
# Out:
# [('key', 'JJ'),
#  ('events', 'NNS'),
#  ('20th', 'JJ'),
#  ('century', 'NN'),
#  ('wikipedia', 'NN'),
#  ('close', 'JJ'),
#  ('november', 'JJ'),
#  ('5th', 'CD'),
#  ('pm', 'NN'),
#  ('wikipedia', 'NN'),
#  ('still', 'RB'),
#  ('ca', 'MD'),
#  ('sold', 'VBN'),
#  ('important', 'JJ'),
#  ('update', 'JJ'),
#  ('readers', 'NNS'),
#  ('germany', 'VBP'),
#  ('today', 'NN'),
#  ('day', 'NN'),
#  ('sorry', 'VB'),
#  ('interrupt', 'JJ'),
#  ('wednesday', 'JJ'),
#  ('5th', 'CD'),
#  ('message', 'NN'),
#  ('hours', 'NNS'),
#  ('ask', 'VBP'),
#  ('reflect', 'JJ'),
#  ('number', 'NN'),
#  ('times', 'NNS'),
#  ('visited', 'JJ'),
#  ('wikipedia', 'NN'),
#  ('past', 'IN'),
#  ('year', 'NN'),
#  ('able', 'JJ'),
#  ('give', 'VBP'),
#  ('back', 'RP'),
#  ('fundraising', 'VBG'),
#  ('appeal', 'NN'),
#  ('displayed', 'VBD'),
#  ('6', 'CD'),
#  ('million', 'CD'),
#  ('times', 'NNS'),
#  ('day', 'NN'),
#  ('currently', 'RB'),
#  ('people', 'NNS'),
#  ('donated', 'VBD'),
#  ('age', 'NN'),
#  ('ai', 'JJ'),
#  ('access', 'NN'),
#  ('verifiable', 'JJ'),
#  ('facts', 'NNS'),
#  ('crucial', 'JJ'),
#  ('wikipedia', 'JJ'),
#  ('heart', 'NN'),
#  ('online', 'NN'),
#  ('information', 'NN'),
#  ('powering', 'VBG'),
#  ('everything', 'NN'),
#  ('personal', 'JJ'),
#  ('searches', 'NNS'),
#  ('emerging', 'VBG'),
#  ('ai', 'NN'),
#  ('technologies', 'NNS'),
#  ('gift', 'VBP'),
#  ('strengthens', 'NNS'),
#  ('knowledge', 'VBP'),
#  ('today', 'NN'),
#  ('tomorrow', 'NN'),
#  ('1', 'CD'),
#  ('readers', 'NNS'),
#  ('donate', 'VB'),
#  ('given', 'VBN'),
#  ('past', 'IN'),
#  ('wikipedia', 'NN'),
#  ('still', 'RB'),
#  ('provides', 'VBZ'),
#  ('worth', 'IN'),
#  ('knowledge', 'NN'),
#  ('kindly', 'RB'),
#  ('donate', 'JJ'),
#  ('today', 'NN'),
#  ('undecided', 'VBD'),
#  ('remember', 'VB'),
#  ('contribution', 'NN'),
#  ('helps', 'VBZ'),
#  ('whether', 'IN'),
#  ('thank', 'NN'),
#  ('target', 'NN'),
#  ('donate', 'NN'),
#  ('often', 'RB'),
#  ('would', 'MD'),
#  ('like', 'VB'),
#  ('donate', 'VB'),
#  ('amount', 'NN'),
#  ('much', 'RB'),
#  ('would', 'MD'),
#  ('like', 'VB'),
#  ('donate', 'NN'),
#  ('using', 'VBG'),
#  ('paypal', 'JJ'),
#  ('logovisa', 'JJ'),
#  ('logomastercard', 'NN'),
#  ('logohow', 'NN'),
#  ('would', 'MD'),
#  ('like', 'VB'),
#  ('pay', 'VB'),
#  ('donation', 'NN'),
#  ('proceed', 'VBN'),
#  ('donation', 'NN'),
#  ('please', 'NN'),
#  ('make', 'VBP'),
#  ('yearly', 'RB'),
#  ('every', 'DT'),
#  ('year', 'NN'),
#  ('dependent', 'JJ'),
#  ('support', 'NN'),
#  ('people', 'NNS'),
#  ('like', 'IN'),
#  ('yearly', 'JJ'),
#  ('donations', 'NNS'),
#  ('help', 'NN'),
#  ('sustainably', 'RB'),
#  ('enable', 'JJ'),
#  ('long', 'JJ'),
#  ('term', 'NN'),
#  ('risks', 'NNS'),
#  ('attached', 'VBN'),
#  ('tell', 'VBP'),
#  ('us', 'PRP'),
#  ('stop', 'VB'),
#  ('donate', 'NN'),
#  ('one', 'CD'),
#  ('donate', 'NN'),
#  ('account', 'NN'),
#  ('wikimedia', 'JJ'),
#  ('bfswde33xxxiban', 'NN'),
#  ('de09', 'NN'),
#  ('3702', 'CD'),
#  ('0500', 'CD'),
#  ('0003', 'CD'),
#  ('2873', 'CD'),
#  ('00', 'CD'),
#  ('already', 'RB'),
#  ('donatedwhere', 'JJ'),
#  ('donation', 'NN'),
#  ('go', 'VBP'),
#  ('closewhere', 'JJ'),
#  ('donation', 'NN'),
#  ('go', 'VBP'),
#  ('wikipedia', 'NN'),
#  ('always', 'RB'),
#  ('reliable', 'JJ'),
#  ('terms', 'NNS'),
#  ('organizational', 'JJ'),
#  ('technical', 'JJ'),
#  ('aspects', 'NNS'),
#  ('future', 'JJ'),
#  ('free', 'JJ'),
#  ('access', 'NN'),
#  ('encyclopedic', 'JJ'),
#  ('trustworthy', 'NN'),
#  ('knowledge', 'NN'),
#  ('times', 'NNS'),
#  ('wherever', 'WDT'),
#  ('also', 'RB'),
#  ('people', 'NNS'),
#  ('around', 'IN'),
#  ('work', 'NN'),
#  ('germany', 'NN'),
#  ('order', 'NN'),
#  ('volunteers', 'NNS'),
#  ('always', 'RB'),
#  ('working', 'VBG'),
#  ('optimal', 'JJ'),
#  ('conditions', 'NNS'),
#  ('wikipedia', 'VBP'),
#  ('fellow', 'JJ'),
#  ('projects', 'NNS'),
#  ('need', 'VBP'),
#  ('best', 'RB'),
#  ('technical', 'JJ'),
#  ('infrastructure', 'NN'),
#  ('furthermore', 'RBR'),
#  ('infrastructure', 'NN'),
#  ('needs', 'VBZ'),
#  ('easy', 'JJ'),
#  ('use', 'NN'),
#  ('development', 'NN'),
#  ('technology', 'NN'),
#  ('behind', 'IN'),
#  ('projects', 'NNS'),
#  ('represents', 'VBZ'),
#  ('greatest', 'JJS'),
#  ('field', 'NN'),
#  ('endeavor', 'NN'),
#  ('terms', 'NNS'),
#  ('staffing', 'VBG'),
#  ('spending', 'NN'),
#  ('commitment', 'NN'),
#  ('area', 'NN'),
#  ('made', 'VBD'),
#  ('us', 'PRP'),
#  ('technical', 'JJ'),
#  ('pioneer', 'NN'),
#  ('volunteers', 'NNS'),
#  ('volunteers', 'NNS'),
#  ('projects', 'NNS'),
#  ('receive', 'VBP'),
#  ('money', 'NN'),
#  ('make', 'VBP'),
#  ('large', 'JJ'),
#  ('investment', 'NN'),
#  ('supporting', 'VBG'),
#  ('wikimedia', 'JJ'),
#  ('steps', 'NNS'),
#  ('volunteer', 'JJ'),
#  ('dedication', 'NN'),
#  ('alone', 'RB'),
#  ('enough', 'RB'),
#  ('organize', 'JJ'),
#  ('events', 'NNS'),
#  ('purchase', 'NN'),
#  ('specialist', 'NN'),
#  ('literature', 'NN'),
#  ('enable', 'JJ'),
#  ('collaborations', 'NNS'),
#  ('supply', 'VBP'),
#  ('photo', 'JJ'),
#  ('equipment', 'NN'),
#  ('photos', 'NNS'),
#  ('wikipedia', 'RB'),
#  ('also', 'RB'),
#  ('provide', 'VBP'),
#  ('funding', 'VBG'),
#  ('local', 'JJ'),
#  ('spaces', 'NNS'),
#  ('various', 'JJ'),
#  ('cities', 'NNS'),
#  ('across', 'IN'),
#  ('germany', 'JJ'),
#  ('volunteers', 'NNS'),
#  ('work', 'VBP'),
#  ('short', 'JJ'),
#  ('whenever', 'WRB'),
#  ('need', 'VBP'),
#  ('wikipedia', 'JJ'),
#  ('projects', 'NNS'),
#  ('across', 'IN'),
#  ('world', 'NN'),
#  ('wikipedia', 'NN'),
#  ('global', 'JJ'),
#  ('project', 'NN'),
#  ('300', 'CD'),
#  ('language', 'NN'),
#  ('versions', 'NNS'),
#  ('secure', 'VBP'),
#  ('develop', 'VB'),
#  ('international', 'JJ'),
#  ('activities', 'NNS'),
#  ('demands', 'VBZ'),
#  ('us', 'PRP'),
#  ('consistent', 'JJ'),
#  ('financial', 'JJ'),
#  ('commitment', 'NN'),
#  ('performant', 'NN'),
#  ('secure', 'NN'),
#  ('technology', 'NN'),
#  ('crucial', 'JJ'),
#  ('wikimedia', 'NN'),
#  ('independently', 'RB'),
#  ('runs', 'VBZ'),
#  ('seven', 'CD'),
#  ('server', 'NN'),
#  ('farms', 'NNS'),
#  ('across', 'IN'),
#  ('globe', 'NN'),
#  ('beyond', 'IN'),
#  ('assist', 'NN'),
#  ('grants', 'NNS'),
#  ('legal', 'JJ'),
#  ('assistance', 'NN'),
#  ('measures', 'NNS'),
#  ('building', 'VBG'),
#  ('thriving', 'VBG'),
#  ('communities', 'NNS'),
#  ('volunteers', 'NNS'),
#  ('costs', 'NNS'),
#  ('colleagues', 'NNS'),
#  ('berlin', 'VBP'),
#  ('office', 'NN'),
#  ('make', 'VBP'),
#  ('sure', 'JJ'),
#  ('organizational', 'JJ'),
#  ('financial', 'JJ'),
#  ('processes', 'NNS'),
#  ('work', 'NN'),
#  ('reliably', 'RB'),
#  ('take', 'VB'),
#  ('care', 'NN'),
#  ('matters', 'NNS'),
#  ('processing', 'VBG'),
#  ('incoming', 'VBG'),
#  ('donations', 'NNS'),
#  ('handling', 'VBG'),
#  ('many', 'JJ'),
#  ('varied', 'JJ'),
#  ('concerns', 'NNS'),
#  ('supporters', 'NNS'),
#  ('also', 'RB'),
#  ('respond', 'VBP'),
#  ('requests', 'NNS'),
#  ('regarding', 'VBG'),
#  ('projects', 'NNS'),
#  ('see', 'VBP'),
#  ('raising', 'VBG'),
#  ('public', 'JJ'),
#  ('even', 'RB'),
#  ('work', 'VBP'),
#  ('closely', 'RB'),
#  ('cultural', 'JJ'),
#  ('institutions', 'NNS'),
#  ('act', 'VB'),
#  ('political', 'JJ'),
#  ('point', 'NN'),
#  ('contact', 'NN'),
#  ('stay', 'VB'),
#  ('active', 'JJ'),
#  ('european', 'JJ'),
#  ('affairs', 'NNS'),
#  ('strive', 'VBP'),
#  ('gain', 'NN'),
#  ('even', 'RB'),
#  ('volunteers', 'NNS'),
#  ('projects', 'NNS'),
#  ('always', 'RB'),
#  ('goal', 'NN'),
#  ('creating', 'VBG'),
#  ('free', 'JJ'),
#  ('knowledge', 'NN'),
#  ('us', 'PRP'),
#  ('donate', 'VBP'),
#  ('nowhow', 'JJ'),
#  ('donation', 'NN'),
#  ('makes', 'VBZ'),
#  ('differenceyour', 'JJ'),
#  ('donation', 'NN'),
#  ('vital', 'JJ'),
#  ('contribution', 'NN'),
#  ('provide', 'IN'),
#  ('everybody', 'NN'),
#  ('around', 'IN'),
#  ('world', 'NN'),
#  ('free', 'JJ'),
#  ('access', 'NN'),
#  ('knowledge', 'NN'),
#  ('donation', 'NN'),
#  ('contribution', 'NN'),
#  ('maintaining', 'VBG'),
#  ('wikipedia', 'JJ'),
#  ('secure', 'NN'),
#  ('stable', 'JJ'),
#  ('infrastructure', 'NN'),
#  ('interface', 'NN'),
#  ('donation', 'NN'),
#  ('backs', 'NNS'),
#  ('efforts', 'NNS'),
#  ('promote', 'VBP'),
#  ('global', 'JJ'),
#  ('establishment', 'NN'),
#  ('regional', 'JJ'),
#  ('wikipedia', 'NN'),
#  ('donation', 'NN'),
#  ('important', 'JJ'),
#  ('source', 'NN'),
#  ('income', 'NN'),
#  ('ensures', 'VBZ'),
#  ('wikipedia', 'WP'),
#  ('remain', 'VBP'),
#  ('independent', 'JJ'),
#  ('advertising', 'NN'),
#  ('commercial', 'JJ'),
#  ('interests', 'NNS'),
#  ('least', 'JJS'),
#  ('donation', 'NN'),
#  ('contribution', 'NN'),
#  ('towards', 'IN'),
#  ('making', 'VBG'),
#  ('sure', 'JJ'),
#  ('always', 'RB'),
#  ('wikipedia', 'VBP'),
#  ('fingertips', 'NNS'),
#  ('personal', 'JJ'),
#  ('source', 'NN'),
#  ('knowledge', 'NN'),
#  ('offering', 'NN'),
#  ('uniquely', 'RB'),
#  ('wide', 'JJ'),
#  ('range', 'NN'),
#  ('information', 'NN'),
#  ('help', 'NN'),
#  ('find', 'VB'),
#  ('answers', 'NNS'),
#  ('need', 'VBP'),
#  ('goal', 'NN'),
#  ('reach', 'VB'),
#  ('million', 'CD'),
#  ('donations', 'NNS'),
#  ('important', 'JJ'),
#  ('part', 'NN'),
#  ('total', 'NN'),
#  ('planned', 'VBD'),
#  ('revenue', 'NN'),
#  ('without', 'IN'),
#  ('doubt', 'NN'),
#  ('lot', 'NN'),
#  ('consider', 'VB'),
#  ('wikipedia', 'JJ'),
#  ('ranks', 'NNS'),
#  ('fifth', 'RB'),
#  ('visited', 'VBD'),
#  ('website', 'JJ'),
#  ('worldwide', 'JJ'),
#  ('figure', 'NN'),
#  ('put', 'VBD'),
#  ('perspective', 'JJ'),
#  ('compared', 'VBN'),
#  ('top', 'JJ'),
#  ('websites', 'NNS'),
#  ('need', 'VBP'),
#  ('extraordinarily', 'RB'),
#  ('small', 'JJ'),
#  ('budget', 'NN'),
#  ('cover', 'NN'),
#  ('running', 'VBG'),
#  ('costs', 'NNS'),
#  ('investments', 'NNS'),
#  ('future', 'JJ'),
#  ('reason', 'NN'),
#  ('possible', 'JJ'),
#  ('wikipedia', 'NN'),
#  ('pursue', 'NN'),
#  ('business', 'NN'),
#  ('model', 'NN'),
#  ('contributions', 'NNS'),
#  ('wikipedia', 'VBP'),
#  ('written', 'VBN'),
#  ('volunteers', 'NNS'),
#  ('around', 'IN'),
#  ('900', 'CD'),
#  ('members', 'NNS'),
#  ('staff', 'NN'),
#  ('worldwide', 'IN'),
#  ('addition', 'NN'),
#  ('organization', 'NN'),
#  ('obliges', 'VBZ'),
#  ('us', 'PRP'),
#  ('handle', 'JJ'),
#  ('revenue', 'NN'),
#  ('responsibly', 'RB'),
#  ('revenue', 'NN'),
#  ('worldwide', 'VB'),
#  ('comparisongoogle', 'NN'),
#  ('348bsourceamazon', 'CD'),
#  ('637bsourcefacebook', 'CD'),
#  ('164bsourcewikipedia', 'CD'),
#  ('donate', 'NN'),
#  ('nowthe', 'NNS'),
#  ('annual', 'JJ'),
#  ('plans', 'NNS'),
#  ('wikimedia', 'VBP'),
#  ('deutschland', 'NN'),
#  ('wikimedia', 'NN'),
#  ('foundation', 'NN'),
#  ('provide', 'VBP'),
#  ('detailed', 'VBN'),
#  ('insight', 'JJ'),
#  ('international', 'JJ'),
#  ('activities', 'NNS'),
#  ('activities', 'NNS'),
#  ('content', 'VBP'),
#  ('main', 'JJ'),
#  ('menu', 'NN'),
#  ('main', 'JJ'),
#  ('menu', 'NN'),
#  ('move', 'NN'),
#  ('sidebar', 'NN'),
#  ('hide', 'NN'),
#  ('navigation', 'NN'),
#  ('main', 'JJ'),
#  ('pagecontentscurrent', 'NN'),
#  ('eventsrandom', 'NN'),
#  ('articleabout', 'IN'),
#  ('wikipediacontact', 'JJ'),
#  ('us', 'PRP'),
#  ('contribute', 'VBP'),
#  ('helplearn', 'JJ'),
#  ('editcommunity', 'NN'),
#  ('portalrecent', 'NN'),
#  ('changesupload', 'NN'),
#  ('filespecial', 'JJ'),
#  ('pages', 'NNS'),
#  ('search', 'VBP'),
#  ('search', 'NN'),
#  ('appearance', 'NN'),
#  ('appearance', 'NN'),
#  ('move', 'NN'),
#  ('sidebar', 'NN'),
#  ('hide', 'NN'),
#  ('textsmallstandardlargethis', 'JJ'),
#  ('page', 'NN'),
#  ('always', 'RB'),
#  ('uses', 'VBZ'),
#  ('small', 'JJ'),
#  ('font', 'RB'),
#  ('sizewidthstandardwidethe', 'JJ'),
#  ('content', 'NN'),
#  ('wide', 'JJ'),
#  ('possible', 'JJ'),
#  ('browser', 'NN'),
#  ('beta', 'NN'),
#  ('automaticlightdarkthis', 'JJ'),
#  ('page', 'NN'),
#  ('always', 'RB'),
#  ('light', 'JJ'),
#  ('mode', 'NNS'),
#  ('donate', 'JJ'),
#  ('create', 'NN'),
#  ('account', 'NN'),
#  ('log', 'JJ'),
#  ('personal', 'JJ'),
#  ('tools', 'NNS'),
#  ('donate', 'VBP'),
#  ('create', 'NN'),
#  ('account', 'NN'),
#  ('log', 'NN'),
#  ('toggle', 'NN'),
#  ('table', 'JJ'),
#  ('contents', 'NNS'),
#  ('contents', 'NNS'),
#  ('move', 'VBP'),
#  ('sidebar', 'NN'),
#  ('hide', 'NN'),
#  ('top', 'JJ'),
#  ('1', 'CD'),
#  ('historic', 'JJ'),
#  ('events', 'NNS'),
#  ('20th', 'JJ'),
#  ('century', 'NN'),
#  ('toggle', 'NN'),
#  ('historic', 'JJ'),
#  ('events', 'NNS'),
#  ('20th', 'JJ'),
#  ('century', 'NN'),
#  ('subsection', 'NN'),
#  ('world', 'NN'),
#  ('beginning', 'VBG'),
#  ('century', 'NN'),
#  ('war', 'NN'),
#  ('end', 'NN'),
#  ('wars', 'NNS'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('spanish', 'JJ'),
#  ('flu', 'NN'),
#  ('russian', 'JJ'),
#  ('revolution', 'NN'),
#  ('communism', 'NN'),
#  ('wars', 'NNS'),
#  ('economic', 'JJ'),
#  ('depression', 'NN'),
#  ('rise', 'NN'),
#  ('dictatorship', 'NN'),
#  ('global', 'JJ'),
#  ('war', 'NN'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('ii', 'JJ'),
#  ('war', 'NN'),
#  ('europe', 'NN'),
#  ('blitzkrieg', 'NN'),
#  ('operation', 'NN'),
#  ('barbarossa', 'IN'),
#  ('turning', 'VBG'),
#  ('tides', 'NNS'),
#  ('operation', 'NN'),
#  ('overlord', 'IN'),
#  ('final', 'JJ'),
#  ('days', 'NNS'),
#  ('war', 'NN'),
#  ('pacific', 'VBP'),
#  ('background', 'IN'),
#  ('japanese', 'JJ'),
#  ('expansion', 'NN'),
#  ('allied', 'VBD'),
#  ('offensive', 'JJ'),
#  ('final', 'JJ'),
#  ('days', 'NNS'),
#  ('holocaust', 'VBP'),
#  ('nuclear', 'JJ'),
#  ('age', 'NN'),
#  ('begins', 'VBZ'),
#  ('world', 'NN'),
#  ('end', 'NN'),
#  ('empires', 'VBZ'),
#  ('decolonization', 'JJ'),
#  ('cold', 'JJ'),
#  ('war', 'NN'),
#  ('war', 'NN'),
#  ('proxy', 'JJ'),
#  ('space', 'NN'),
#  ('race', 'NN'),
#  ('end', 'NN'),
#  ('cold', 'JJ'),
#  ('war', 'NN'),
#  ('information', 'NN'),
#  ('communications', 'NNS'),
#  ('technology', 'NN'),
#  ('world', 'NN'),
#  ('end', 'NN'),
#  ('century', 'NN'),
#  ('2', 'CD'),
#  ('see', 'NN'),
#  ('also', 'RB'),
#  ('3', 'CD'),
#  ('references', 'NNS'),
#  ('4', 'CD'),
#  ('sources', 'NNS'),
#  ('5', 'CD'),
#  ('external', 'JJ'),
#  ('links', 'NNS'),
#  ('key', 'JJ'),
#  ('events', 'NNS'),
#  ('20th', 'JJ'),
#  ('century', 'NN'),
#  ('2', 'CD'),
#  ('languages', 'NNS'),
#  ('العربيةукраїнська', 'VBP'),
#  ('edit', 'JJ'),
#  ('links', 'NNS'),
#  ('articletalk', 'VBP'),
#  ('english', 'JJ'),
#  ('readeditview', 'NN'),
#  ('history', 'NN'),
#  ('tools', 'NNS'),
#  ('tools', 'NNS'),
#  ('move', 'VBP'),
#  ('sidebar', 'NN'),
#  ('hide', 'NN'),
#  ('actions', 'NNS'),
#  ('readeditview', 'VBP'),
#  ('history', 'NN'),
#  ('general', 'JJ'),
#  ('links', 'NNS'),
#  ('hererelated', 'VBD'),
#  ('changesupload', 'JJ'),
#  ('filepermanent', 'JJ'),
#  ('linkpage', 'NN'),
#  ('informationcite', 'JJ'),
#  ('pageget', 'NN'),
#  ('shortened', 'VBD'),
#  ('urldownload', 'JJ'),
#  ('qr', 'NN'),
#  ('code', 'NN'),
#  ('expand', 'VBP'),
#  ('alledit', 'NN'),
#  ('interlanguage', 'NN'),
#  ('links', 'NNS'),
#  ('download', 'VBP'),
#  ('pdfprintable', 'JJ'),
#  ('version', 'NN'),
#  ('projects', 'NNS'),
#  ('wikimedia', 'VBP'),
#  ('commonswikidata', 'JJ'),
#  ('item', 'NN'),
#  ('wikipedia', 'VBD'),
#  ('free', 'JJ'),
#  ('encyclopedia', 'NN'),
#  ('20th', 'JJ'),
#  ('century', 'NN'),
#  ('changed', 'VBD'),
#  ('world', 'NN'),
#  ('unprecedented', 'JJ'),
#  ('ways', 'NNS'),
#  ('world', 'NN'),
#  ('wars', 'NNS'),
#  ('sparked', 'VBD'),
#  ('tension', 'NN'),
#  ('countries', 'NNS'),
#  ('led', 'VBD'),
#  ('creation', 'NN'),
#  ('atomic', 'JJ'),
#  ('bombs', 'NNS'),
#  ('cold', 'JJ'),
#  ('war', 'NN'),
#  ('led', 'VBD'),
#  ('space', 'NN'),
#  ('race', 'NN'),
#  ('creation', 'NN'),
#  ('rockets', 'NNS'),
#  ('world', 'NN'),
#  ('wide', 'JJ'),
#  ('web', 'NN'),
#  ('created', 'VBD'),
#  ('advancements', 'NNS'),
#  ('played', 'VBD'),
#  ('significant', 'JJ'),
#  ('role', 'NN'),
#  ('citizens', 'NNS'),
#  ('lives', 'VBZ'),
#  ('shaped', 'VBD'),
#  ('21st', 'JJ'),
#  ('century', 'NN'),
#  ('today', 'NN'),
#  ('historic', 'JJ'),
#  ('events', 'NNS'),
#  ('20th', 'JJ'),
#  ('century', 'NN'),
#  ('edit', 'NN'),
#  ('world', 'NN'),
#  ('beginning', 'VBG'),
#  ('century', 'NN'),
#  ('edit', 'NN'),
#  ('main', 'JJ'),
#  ('article', 'NN'),
#  ('edwardian', 'JJ'),
#  ('era', 'NN'),
#  ('new', 'JJ'),
#  ('beginning', 'VBG'),
#  ('20th', 'JJ'),
#  ('century', 'NN'),
#  ('marked', 'VBD'),
#  ('significant', 'JJ'),
#  ('changes', 'NNS'),
#  ('1900s', 'CD'),
#  ('saw', 'VBD'),
#  ('decade', 'NN'),
#  ('herald', 'NN'),
#  ('series', 'NN'),
#  ('inventions', 'NNS'),
#  ('including', 'VBG'),
#  ('automobile', 'NN'),
#  ('airplane', 'NN'),
#  ('radio', 'NN'),
#  ('broadcasting', 'NN'),
#  ('1914', 'CD'),
#  ('saw', 'NN'),
#  ('completion', 'NN'),
#  ('panama', 'IN'),
#  ('canal', 'JJ'),
#  ('scramble', 'NN'),
#  ('africa', 'NN'),
#  ('continued', 'VBD'),
#  ('1900s', 'CD'),
#  ('resulted', 'VBD'),
#  ('wars', 'NNS'),
#  ('genocide', 'JJ'),
#  ('across', 'IN'),
#  ('continent', 'NN'),
#  ('atrocities', 'NNS'),
#  ('congo', 'VBP'),
#  ('free', 'JJ'),
#  ('state', 'NN'),
#  ('shocked', 'VBD'),
#  ('civilized', 'JJ'),
#  ('world', 'NN'),
#  ('1914', 'CD'),
#  ('1918', 'CD'),
#  ('first', 'JJ'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('aftermath', 'NN'),
#  ('caused', 'VBD'),
#  ('major', 'JJ'),
#  ('changes', 'NNS'),
#  ('power', 'NN'),
#  ('balance', 'NN'),
#  ('world', 'NN'),
#  ('destroying', 'VBG'),
#  ('transforming', 'VBG'),
#  ('powerful', 'JJ'),
#  ('empires', 'NNS'),
#  ('war', 'NN'),
#  ('end', 'NN'),
#  ('wars', 'NNS'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('edit', 'NN'),
#  ('main', 'JJ'),
#  ('article', 'NN'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('arrest', 'NN'),
#  ('suspect', 'NN'),
#  ('sarajevo', 'NN'),
#  ('following', 'VBG'),
#  ('assassination', 'NN'),
#  ('archduke', 'IN'),
#  ('franz', 'NN'),
#  ('ferdinand', 'NN'),
#  ('first', 'JJ'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('simply', 'RB'),
#  ('wwi', 'VBD'),
#  ('termed', 'JJ'),
#  ('great', 'JJ'),
#  ('war', 'NN'),
#  ('contemporaries', 'NNS'),
#  ('started', 'VBD'),
#  ('july', 'JJ'),
#  ('1914', 'CD'),
#  ('ended', 'VBD'),
#  ('november', 'NNP'),
#  ('war', 'NN'),
#  ('precipitated', 'VBD'),
#  ('assassination', 'NN'),
#  ('sarajevo', 'NN'),
#  ('empire', 'VBP'),
#  ('heir', 'NN'),
#  ('throne', 'NN'),
#  ('erzherzog', 'NN'),
#  ('franz', 'NN'),
#  ('ferdinand', 'NN'),
#  ('gavrilo', 'NN'),
#  ('princip', 'NN'),
#  ('member', 'NN'),
#  ('young', 'JJ'),
#  ('bosnia', 'NN'),
#  ('liberation', 'NN'),
#  ('movement', 'NN'),
#  ('period', 'NN'),
#  ('diplomatic', 'JJ'),
#  ('military', 'JJ'),
#  ('escalation', 'NN'),
#  ('known', 'VBN'),
#  ('july', 'NN'),
#  ('crisis', 'NN'),
#  ('end', 'NN'),
#  ('july', 'NN'),
#  ('1914', 'CD'),
#  ('two', 'CD'),
#  ('coalitions', 'NNS'),
#  ('war', 'NN'),
#  ('allies', 'NNS'),
#  ('comprised', 'VBN'),
#  ('initially', 'RB'),
#  ('british', 'JJ'),
#  ('empire', 'NN'),
#  ('france', 'NN'),
#  ('russian', 'JJ'),
#  ('empire', 'NN'),
#  ('central', 'JJ'),
#  ('powers', 'NNS'),
#  ('comprised', 'VBD'),
#  ('initially', 'RB'),
#  ('german', 'JJ'),
#  ('empire', 'NN'),
#  ('1917', 'CD'),
#  ('russia', 'NN'),
#  ('ended', 'VBN'),
#  ('hostile', 'JJ'),
#  ('actions', 'NNS'),
#  ('central', 'JJ'),
#  ('powers', 'NNS'),
#  ('fall', 'VBP'),
#  ('tsar', 'JJ'),
#  ('bolsheviks', 'NN'),
#  ('negotiated', 'VBD'),
#  ('treaty', 'RB'),
#  ('germany', 'JJ'),
#  ('although', 'IN'),
#  ('huge', 'JJ'),
#  ('cost', 'NN'),
#  ('russia', 'NN'),
#  ('treaty', 'NN'),
#  ('bolshevik', 'NN'),
#  ('russia', 'NN'),
#  ('ceded', 'VBD'),
#  ('baltic', 'JJ'),
#  ('states', 'NNS'),
#  ('germany', 'JJ'),
#  ('province', 'NN'),
#  ('kars', 'NNS'),
#  ('oblast', 'IN'),
#  ('south', 'JJ'),
#  ('caucasus', 'NN'),
#  ('ottoman', 'NN'),
#  ('empire', 'NN'),
#  ('also', 'RB'),
#  ('recognized', 'VBN'),
#  ('independence', 'NN'),
#  ('ukraine', 'NN'),
#  ('although', 'IN'),
#  ('germany', 'NN'),
#  ('shifted', 'VBD'),
#  ('huge', 'JJ'),
#  ('forces', 'NNS'),
#  ('eastern', 'JJ'),
#  ('western', 'JJ'),
#  ('front', 'NN'),
#  ('signing', 'VBG'),
#  ('treaty', 'NN'),
#  ('unable', 'JJ'),
#  ('stop', 'NN'),
#  ('allied', 'VBD'),
#  ('advance', 'NN'),
#  ('especially', 'RB'),
#  ('entrance', 'JJ'),
#  ('american', 'JJ'),
#  ('troops', 'NNS'),
#  ('war', 'NN'),
#  ('also', 'RB'),
#  ('chance', 'NN'),
#  ('combatant', 'JJ'),
#  ('nations', 'NNS'),
#  ('show', 'VBP'),
#  ('military', 'JJ'),
#  ('strength', 'NN'),
#  ('technological', 'JJ'),
#  ('ingenuity', 'NN'),
#  ('germans', 'NNS'),
#  ('introduced', 'VBD'),
#  ('machine', 'NN'),
#  ('gun', 'NN'),
#  ('deadly', 'JJ'),
#  ('gases', 'NNS'),
#  ('british', 'JJ'),
#  ('first', 'RB'),
#  ('used', 'VBD'),
#  ('tank', 'NN'),
#  ('sides', 'NNS'),
#  ('chance', 'NN'),
#  ('test', 'VBP'),
#  ('new', 'JJ'),
#  ('aircraft', 'NNS'),
#  ('see', 'NN'),
#  ('could', 'MD'),
#  ('used', 'VBN'),
#  ('warfare', 'VB'),
#  ('widely', 'RB'),
#  ('believed', 'VBN'),
#  ('war', 'NN'),
#  ('would', 'MD'),
#  ('short', 'VB'),
#  ('unfortunately', 'RB'),
#  ('since', 'IN'),
#  ('trench', 'NN'),
#  ('warfare', 'NN'),
#  ('best', 'RBS'),
#  ('form', 'NN'),
#  ('defense', 'NN'),
#  ('advances', 'NNS'),
#  ('sides', 'NNS'),
#  ('slow', 'VBP'),
#  ('came', 'VBD'),
#  ('terrible', 'JJ'),
#  ('cost', 'NN'),
#  ('lives', 'NNS'),
#  ('division', 'NN'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('war', 'NN'),
#  ('finally', 'RB'),
#  ('1918', 'CD'),
#  ('results', 'NNS'),
#  ('would', 'MD'),
#  ('set', 'VB'),
#  ('stage', 'NN'),
#  ('next', 'JJ'),
#  ('twenty', 'NN'),
#  ('years', 'NNS'),
#  ('first', 'RB'),
#  ('foremost', 'RB'),
#  ('germans', 'NNS'),
#  ('forced', 'VBD'),
#  ('sign', 'NN'),
#  ('treaty', 'NN'),
#  ('versailles', 'NNS'),
#  ('forcing', 'VBG'),
#  ('make', 'VBP'),
#  ('exorbitant', 'JJ'),
#  ('payments', 'NNS'),
#  ('repair', 'NN'),
#  ('damages', 'NNS'),
#  ('caused', 'VBD'),
#  ('war', 'NN'),
#  ('many', 'JJ'),
#  ('germans', 'NNS'),
#  ('felt', 'VBD'),
#  ('reparations', 'NNS'),
#  ('unfair', 'JJ'),
#  ('actually', 'RB'),
#  ('lose', 'VBP'),
#  ('war', 'NN'),
#  ('feel', 'NN'),
#  ('caused', 'VBD'),
#  ('war', 'NN'),
#  ('see', 'NN'),
#  ('legend', 'VBP'),
#  ('germany', 'NN'),
#  ...]

# %%
df_text = pd.DataFrame(tags_list)
df_text.columns = ['Words', "Word type"]

# %%
df_text
# Out:
#            Words Word type
# 0            key        JJ
# 1         events       NNS
# 2           20th        JJ
# 3        century        NN
# 4      wikipedia        NN
# ...          ...       ...
# 11485    century        NN
# 11486          2        CD
# 11487  languages       NNS
# 11488        add       VBP
# 11489      topic        NN
#
# [11490 rows x 2 columns]

# %%
df_text = pd.DataFrame(tags_list)
df_text.columns = [ 'Words', "Word type"]
df_t=df_text.groupby('Word type').count().reset_index()
top20=df_t.nlargest(20, 'Words')

# %%
df_t.head()
# Out:
#   Word type  Words
# 0        CC      7
# 1        CD   1292
# 2        DT      8
# 3        FW     22
# 4        IN    172

# %%
plt.figure(figsize = (10, 5))
with sns.dark_palette("xkcd:blue", 20):
      sns.barplot(x = "Words", y = "Word type",
     saturation = 0.9, data = top20).set_title("20th_century - top 20 word types used")

# %%
#most used verbs

df = df_text[(df_text['Word type'] == "VB")  | (df_text['Word type'] == "VBD")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top15 = y.nlargest(15, 'Occurences')

# %%
plt.figure(figsize=(15, 5))
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x="Word", y="Occurences",
    saturation=0.9, data = top15).set_title("20th_century - most frequently used verbs")

# %%
#most used nouns

df = df_text[(df_text['Word type'] == "NN")  | (df_text['Word type'] == "NNS")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top15 = y.nlargest(15, 'Occurences')

# %%
plt.figure(figsize=(15, 5))
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x="Word", y="Occurences",
    saturation=0.9, data = top15).set_title("20th_century - most frequently used nouns")

# %%
#most used adjectives

df = df_text[(df_text['Word type'] == "JJ")  | (df_text['Word type'] == "JJS")  | (df_text['Word type'] == "JJR")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top15 = y.nlargest(15, 'Occurences')

# %%
plt.figure(figsize=(15, 5))
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x="Word", y="Occurences",
    saturation=0.9, data = top15).set_title("20th_century - most frequently used adjectives")

# %% [markdown]
# # Notes
#
# Even for one without historic knowledge, these charts tell quite a coherent story about the historical tone in the 20th century. Which was marked by terrific global conflicts and wars.

# %%
#country frequencies

# %% [markdown]
# # Notes
#
# The website's perspective of the 20th century is centered on big global powers and wars, rather than cultural or economic events. The Top 5 countries by mention are :Japan, Germany, the US, France and Italy.
#
# Europe: Germany, France, Italy, Poland, Austria, Finland, Slovakia, Lithuania, Norway
# Both world wars were mostly fought on european grounds , therefor a higher frequency of european countries from a western standpoint is apparent.
#
# North America: The United States ranks among the top 3, reflecting its strong involvement throughout the century. The US alone spend 25 years of the 20th century involved and participating in wars ( war on vietnam, part of the allied forces in the second world war, korean war, attacks on cuba...).
#
# Asia: Japan and China are in the top ten, both were key players in WWII and later Cold War developments. Additionally the manchuria war (Japan against china).

# %%
# Countries with list

# %%
countries = [
    "Afghanistan", "Albania", "Algeria", "Andorra", "Angola", "Argentina", "Armenia", "Australia",
    "Austria", "Azerbaijan", "Bahamas", "Bahrain", "Bangladesh", "Barbados", "Belarus", "Belgium",
    "Belize", "Benin", "Bhutan", "Bolivia", "Bosnia", "Botswana", "Brazil", "Brunei", "Bulgaria",
    "Burkina Faso", "Burundi", "Cambodia", "Cameroon", "Canada", "Cape Verde", "Chad", "Chile",
    "China", "Colombia", "Comoros", "Costa Rica", "Croatia", "Cuba", "Cyprus", "Czech Republic",
    "Denmark", "Djibouti", "Dominica", "Dominican Republic", "Ecuador", "Egypt", "El Salvador",
    "Equatorial Guinea", "Eritrea", "Estonia", "Eswatini", "Ethiopia", "Fiji", "Finland", "France",
    "Gabon", "Gambia", "Georgia", "Germany", "Ghana", "Greece", "Grenada", "Guatemala", "Guinea",
    "Guyana", "Haiti", "Honduras", "Hungary", "Iceland", "India", "Indonesia", "Iran", "Iraq",
    "Ireland", "Israel", "Italy", "Jamaica", "Japan", "Jordan", "Kazakhstan", "Kenya", "Kiribati",
    "Kuwait", "Kyrgyzstan", "Laos", "Latvia", "Lebanon", "Lesotho", "Liberia", "Libya",
    "Liechtenstein", "Lithuania", "Luxembourg", "Madagascar", "Malawi", "Malaysia", "Maldives",
    "Mali", "Malta", "Mauritania", "Mauritius", "Mexico", "Micronesia", "Moldova", "Monaco",
    "Mongolia", "Montenegro", "Morocco", "Mozambique", "Myanmar", "Namibia", "Nauru", "Nepal",
    "Netherlands", "New Zealand", "Nicaragua", "Niger", "Nigeria", "North Korea", "North Macedonia",
    "Norway", "Oman", "Pakistan", "Palau", "Panama", "Papua New Guinea", "Paraguay", "Peru",
    "Philippines", "Poland", "Portugal", "Qatar", "Romania", "Russia", "Rwanda", "Saint Lucia",
    "Samoa", "San Marino", "Saudi Arabia", "Senegal", "Serbia", "Seychelles", "Sierra Leone",
    "Singapore", "Slovakia", "Slovenia", "Somalia", "South Africa", "South Korea", "Spain",
    "Sri Lanka", "Sudan", "Suriname", "Sweden", "Switzerland", "Syria", "Taiwan", "Tajikistan",
    "Tanzania", "Thailand", "Togo", "Tonga", "Trinidad", "Tunisia", "Turkey", "Turkmenistan",
    "Uganda", "Ukraine", "United Arab Emirates", "United Kingdom", "United States", "Uruguay",
    "Uzbekistan", "Vanuatu", "Vatican", "Venezuela", "Vietnam", "Yemen", "Zambia", "Zimbabwe"
]

# %%
listToStr = ' '.join([str(elem) for elem in dist_words_filter_2])
 
print(listToStr)
# Out:
# 2018 december retrieved war was on world as by with history that it were which soviet this at new first 20 hitler 12 century had germany would its 13 is battle nuclear after 11 an but states japan end japanese germans union be their not german united september 15 only his issn became europe july august weapons all they many into main nations during space against june people one other army april 18 27 20th over or most africa attack may you between holocaust american october computer our two stalin second north bbc wikipedia allied countries allies britain wars what british forces 17 however invasion november we have us free cold great could he nazi how january more berlin such economic france time jews east later been internet archived 1 these international government about 7 february press day made operation 2 led military crisis south when did air 1945 national york under rise pacific 5 general article state some out italy began 16 2017 original up times 6 million i now use why both where project days 3 major power known treaty used came years news early poland atlantic march vietnam events like see troops launched despite 1942 university donate are them global offensive atomic eastern imperial communist force almost pact french several largest 8 naval west island surrender computers richard year if your any donation political european organization revolution communism including empire powers independence western human 29 9 14 bomb campaign 26 1944 camps peace john software 2011 guardian important information already further even independent part planned foundation depression russia fall aircraft warfare next system mussolini 23 attacks sea 10 launch network city churchill last china india death korea 21 2012 2016 2014 2015 still today wikimedia terms need development large than beginning race 4 changed creation 1918 central forced among leading joseph plan battles territory 1940 nazis influence 30 islands korean museums journal few number personal knowledge much work volunteers projects technology behind area across there because possible russian created 21st although advance since form set groups pandemic country articles fascism took ussr winter defeat surrendered throughout 28 being third turned eventually bombing rommel place who 25 chinese macarthur 19 robert while systems michael ssr video pc company networks pmid interest s2cid publishing age online using help each always future around has no provide cities short develop having office efforts worldwide put business dictatorship turning final decolonization lives continued caused powerful following ended occupied upon own league within rule capitalist soon conference control held secret massive paris three suffered turn weapon 22 group 6th harbor victory man half another occupation asia station killed president concentration knew program 1980s african missile ibm story 2003 2009 2008 research close back facts crucial given often make long can take commercial wide range small create expansion links code encyclopedia marked saw started period baltic itself tank advances very division finally never yugoslavia czechoslovakia medical ending de leader idea well strong through become market society soldiers population civil moscow attacked change republics norway six entire refused managed italians taking down modern signed divided b libya pearl 1943 victories followed invaded site too leaders newly yalta conflict until philippines foreign strategic tokyo home nation developed 24 involved formation decades cuban apollo problem games timeline art archives politics daniel museum david heritage 2013 2nd science key 5th past access so contribution does technical best greatest supply do beyond same goal remain top members plans move sidebar hide search table historic spanish barbarossa overlord empires web 1914 continent movement initially cost especially sign ethnic former called limited spread poor regime socialist economy solution 1930s remained leadership little ordinary inte ...

# %%
all_counts = Counter(re.sub(r'\W+', ' ', listToStr).split())

# %%
all_counts
# Out:
# Counter({'2018': 1,
#          'december': 1,
#          'retrieved': 1,
#          'war': 1,
#          'was': 1,
#          'on': 1,
#          'world': 1,
#          'as': 1,
#          'by': 1,
#          'with': 1,
#          'history': 1,
#          'that': 1,
#          'it': 1,
#          'were': 1,
#          'which': 1,
#          'soviet': 1,
#          'this': 1,
#          'at': 1,
#          'new': 1,
#          'first': 1,
#          '20': 1,
#          'hitler': 1,
#          '12': 1,
#          'century': 1,
#          'had': 1,
#          'germany': 1,
#          'would': 1,
#          'its': 1,
#          '13': 1,
#          'is': 1,
#          'battle': 1,
#          'nuclear': 1,
#          'after': 1,
#          '11': 1,
#          'an': 1,
#          'but': 1,
#          'states': 1,
#          'japan': 1,
#          'end': 1,
#          'japanese': 1,
#          'germans': 1,
#          'union': 1,
#          'be': 1,
#          'their': 1,
#          'not': 1,
#          'german': 1,
#          'united': 1,
#          'september': 1,
#          '15': 1,
#          'only': 1,
#          'his': 1,
#          'issn': 1,
#          'became': 1,
#          'europe': 1,
#          'july': 1,
#          'august': 1,
#          'weapons': 1,
#          'all': 1,
#          'they': 1,
#          'many': 1,
#          'into': 1,
#          'main': 1,
#          'nations': 1,
#          'during': 1,
#          'space': 1,
#          'against': 1,
#          'june': 1,
#          'people': 1,
#          'one': 1,
#          'other': 1,
#          'army': 1,
#          'april': 1,
#          '18': 1,
#          '27': 1,
#          '20th': 1,
#          'over': 1,
#          'or': 1,
#          'most': 1,
#          'africa': 1,
#          'attack': 1,
#          'may': 1,
#          'you': 1,
#          'between': 1,
#          'holocaust': 1,
#          'american': 1,
#          'october': 1,
#          'computer': 1,
#          'our': 1,
#          'two': 1,
#          'stalin': 1,
#          'second': 1,
#          'north': 1,
#          'bbc': 1,
#          'wikipedia': 1,
#          'allied': 1,
#          'countries': 1,
#          'allies': 1,
#          'britain': 1,
#          'wars': 1,
#          'what': 1,
#          'british': 1,
#          'forces': 1,
#          '17': 1,
#          'however': 1,
#          'invasion': 1,
#          'november': 1,
#          'we': 1,
#          'have': 1,
#          'us': 1,
#          'free': 1,
#          'cold': 1,
#          'great': 1,
#          'could': 1,
#          'he': 1,
#          'nazi': 1,
#          'how': 1,
#          'january': 1,
#          'more': 1,
#          'berlin': 1,
#          'such': 1,
#          'economic': 1,
#          'france': 1,
#          'time': 1,
#          'jews': 1,
#          'east': 1,
#          'later': 1,
#          'been': 1,
#          'internet': 1,
#          'archived': 1,
#          '1': 1,
#          'these': 1,
#          'international': 1,
#          'government': 1,
#          'about': 1,
#          '7': 1,
#          'february': 1,
#          'press': 1,
#          'day': 1,
#          'made': 1,
#          'operation': 1,
#          '2': 1,
#          'led': 1,
#          'military': 1,
#          'crisis': 1,
#          'south': 1,
#          'when': 1,
#          'did': 1,
#          'air': 1,
#          '1945': 1,
#          'national': 1,
#          'york': 1,
#          'under': 1,
#          'rise': 1,
#          'pacific': 1,
#          '5': 1,
#          'general': 1,
#          'article': 1,
#          'state': 1,
#          'some': 1,
#          'out': 1,
#          'italy': 1,
#          'began': 1,
#          '16': 1,
#          '2017': 1,
#          'original': 1,
#          'up': 1,
#          'times': 1,
#          '6': 1,
#          'million': 1,
#          'i': 1,
#          'now': 1,
#          'use': 1,
#          'why': 1,
#          'both': 1,
#          'where': 1,
#          'project': 1,
#          'days': 1,
#          '3': 1,
#          'major': 1,
#          'power': 1,
#          'known': 1,
#          'treaty': 1,
#          'used': 1,
#          'came': 1,
#          'years': 1,
#          'news': 1,
#          'early': 1,
#          'poland': 1,
#          'atlantic': 1,
#          'march': 1,
#          'vietnam': 1,
#          'events': 1,
#          'like': 1,
#          'see': 1,
#          'troops': 1,
#          'launched': 1,
#          'despite': 1,
#          '1942': 1,
#          'university': 1,
#          'donate': 1,
#          'are': 1,
#          'them': 1,
#          'global': 1,
#          'offensive': 1,
#          'atomic': 1,
#          'eastern': 1,
#          'imperial': 1,
#          'communist': 1,
#          'force': 1,
#          'almost': 1,
#          'pact': 1,
#          'french': 1,
#          'several': 1,
#          'largest': 1,
#          '8': 1,
#          'naval': 1,
#          'west': 1,
#          'island': 1,
#          'surrender': 1,
#          'computers': 1,
#          'richard': 1,
#          'year': 1,
#          'if': 1,
#          'your': 1,
#          'any': 1,
#          'donation': 1,
#          'political': 1,
#          'european': 1,
#          'organization': 1,
#          'revolution': 1,
#          'communism': 1,
#          'including': 1,
#          'empire': 1,
#          'powers': 1,
#          'independence': 1,
#          'western': 1,
#          'human': 1,
#          '29': 1,
#          '9': 1,
#          '14': 1,
#          'bomb': 1,
#          'campaign': 1,
#          '26': 1,
#          '1944': 1,
#          'camps': 1,
#          'peace': 1,
#          'john': 1,
#          'software': 1,
#          '2011': 1,
#          'guardian': 1,
#          'important': 1,
#          'information': 1,
#          'already': 1,
#          'further': 1,
#          'even': 1,
#          'independent': 1,
#          'part': 1,
#          'planned': 1,
#          'foundation': 1,
#          'depression': 1,
#          'russia': 1,
#          'fall': 1,
#          'aircraft': 1,
#          'warfare': 1,
#          'next': 1,
#          'system': 1,
#          'mussolini': 1,
#          '23': 1,
#          'attacks': 1,
#          'sea': 1,
#          '10': 1,
#          'launch': 1,
#          'network': 1,
#          'city': 1,
#          'churchill': 1,
#          'last': 1,
#          'china': 1,
#          'india': 1,
#          'death': 1,
#          'korea': 1,
#          '21': 1,
#          '2012': 1,
#          '2016': 1,
#          '2014': 1,
#          '2015': 1,
#          'still': 1,
#          'today': 1,
#          'wikimedia': 1,
#          'terms': 1,
#          'need': 1,
#          'development': 1,
#          'large': 1,
#          'than': 1,
#          'beginning': 1,
#          'race': 1,
#          '4': 1,
#          'changed': 1,
#          'creation': 1,
#          '1918': 1,
#          'central': 1,
#          'forced': 1,
#          'among': 1,
#          'leading': 1,
#          'joseph': 1,
#          'plan': 1,
#          'battles': 1,
#          'territory': 1,
#          '1940': 1,
#          'nazis': 1,
#          'influence': 1,
#          '30': 1,
#          'islands': 1,
#          'korean': 1,
#          'museums': 1,
#          'journal': 1,
#          'few': 1,
#          'number': 1,
#          'personal': 1,
#          'knowledge': 1,
#          'much': 1,
#          'work': 1,
#          'volunteers': 1,
#          'projects': 1,
#          'technology': 1,
#          'behind': 1,
#          'area': 1,
#          'across': 1,
#          'there': 1,
#          'because': 1,
#          'possible': 1,
#          'russian': 1,
#          'created': 1,
#          '21st': 1,
#          'although': 1,
#          'advance': 1,
#          'since': 1,
#          'form': 1,
#          'set': 1,
#          'groups': 1,
#          'pandemic': 1,
#          'country': 1,
#          'articles': 1,
#          'fascism': 1,
#          'took': 1,
#          'ussr': 1,
#          'winter': 1,
#          'defeat': 1,
#          'surrendered': 1,
#          'throughout': 1,
#          '28': 1,
#          'being': 1,
#          'third': 1,
#          'turned': 1,
#          'eventually': 1,
#          'bombing': 1,
#          'rommel': 1,
#          'place': 1,
#          'who': 1,
#          '25': 1,
#          'chinese': 1,
#          'macarthur': 1,
#          '19': 1,
#          'robert': 1,
#          'while': 1,
#          'systems': 1,
#          'michael': 1,
#          'ssr': 1,
#          'video': 1,
#          'pc': 1,
#          'company': 1,
#          'networks': 1,
#          'pmid': 1,
#          'interest': 1,
#          's2cid': 1,
#          'publishing': 1,
#          'age': 1,
#          'online': 1,
#          'using': 1,
#          'help': 1,
#          'each': 1,
#          'always': 1,
#          'future': 1,
#          'around': 1,
#          'has': 1,
#          'no': 1,
#          'provide': 1,
#          'cities': 1,
#          'short': 1,
#          'develop': 1,
#          'having': 1,
#          'office': 1,
#          'efforts': 1,
#          'worldwide': 1,
#          'put': 1,
#          'business': 1,
#          'dictatorship': 1,
#          'turning': 1,
#          'final': 1,
#          'decolonization': 1,
#          'lives': 1,
#          'continued': 1,
#          'caused': 1,
#          'powerful': 1,
#          'following': 1,
#          'ended': 1,
#          'occupied': 1,
#          'upon': 1,
#          'own': 1,
#          'league': 1,
#          'within': 1,
#          'rule': 1,
#          'capitalist': 1,
#          'soon': 1,
#          'conference': 1,
#          'control': 1,
#          'held': 1,
#          'secret': 1,
#          'massive': 1,
#          'paris': 1,
#          'three': 1,
#          'suffered': 1,
#          'turn': 1,
#          'weapon': 1,
#          '22': 1,
#          'group': 1,
#          '6th': 1,
#          'harbor': 1,
#          'victory': 1,
#          'man': 1,
#          'half': 1,
#          'another': 1,
#          'occupation': 1,
#          'asia': 1,
#          'station': 1,
#          'killed': 1,
#          'president': 1,
#          'concentration': 1,
#          'knew': 1,
#          'program': 1,
#          '1980s': 1,
#          'african': 1,
#          'missile': 1,
#          'ibm': 1,
#          'story': 1,
#          '2003': 1,
#          '2009': 1,
#          '2008': 1,
#          'research': 1,
#          'close': 1,
#          'back': 1,
#          'facts': 1,
#          'crucial': 1,
#          'given': 1,
#          'often': 1,
#          'make': 1,
#          'long': 1,
#          'can': 1,
#          'take': 1,
#          'commercial': 1,
#          'wide': 1,
#          'range': 1,
#          'small': 1,
#          'create': 1,
#          'expansion': 1,
#          'links': 1,
#          'code': 1,
#          'encyclopedia': 1,
#          'marked': 1,
#          'saw': 1,
#          'started': 1,
#          'period': 1,
#          'baltic': 1,
#          'itself': 1,
#          'tank': 1,
#          'advances': 1,
#          'very': 1,
#          'division': 1,
#          'finally': 1,
#          'never': 1,
#          'yugoslavia': 1,
#          'czechoslovakia': 1,
#          'medical': 1,
#          'ending': 1,
#          'de': 1,
#          'leader': 1,
#          'idea': 1,
#          'well': 1,
#          'strong': 1,
#          'through': 1,
#          'become': 1,
#          'market': 1,
#          'society': 1,
#          'soldiers': 1,
#          'population': 1,
#          'civil': 1,
#          'moscow': 1,
#          'attacked': 1,
#          'change': 1,
#          'republics': 1,
#          'norway': 1,
#          'six': 1,
#          'entire': 1,
#          'refused': 1,
#          'managed': 1,
#          'italians': 1,
#          'taking': 1,
#          'down': 1,
#          'modern': 1,
#          'signed': 1,
#          'divided': 1,
#          'b': 1,
#          'libya': 1,
#          'pearl': 1,
#          '1943': 1,
#          'victories': 1,
#          'followed': 1,
#          'invaded': 1,
#          'site': 1,
#          'too': 1,
#          'leaders': 1,
#          'newly': 1,
#          'yalta': 1,
#          'conflict': 1,
#          'until': 1,
#          'philippines': 1,
#          'foreign': 1,
#          'strategic': 1,
#          'tokyo': 1,
#          'home': 1,
#          'nation': 1,
#          'developed': 1,
#          '24': 1,
#          'involved': 1,
#          'formation': 1,
#          'decades': 1,
#          'cuban': 1,
#          'apollo': 1,
#          'problem': 1,
#          'games': 1,
#          'timeline': 1,
#          'art': 1,
#          'archives': 1,
#          'politics': 1,
#          'daniel': 1,
#          'museum': 1,
#          'david': 1,
#          'heritage': 1,
#          '2013': 1,
#          '2nd': 1,
#          'science': 1,
#          'key': 1,
#          '5th': 1,
#          'past': 1,
#          'access': 1,
#          'so': 1,
#          'contribution': 1,
#          'does': 1,
#          'technical': 1,
#          'best': 1,
#          'greatest': 1,
#          'supply': 1,
#          'do': 1,
#          'beyond': 1,
#          'same': 1,
#          'goal': 1,
#          'remain': 1,
#          'top': 1,
#          'members': 1,
#          'plans': 1,
#          'move': 1,
#          'sidebar': 1,
#          'hide': 1,
#          'search': 1,
#          'table': 1,
#          'historic': 1,
#          'spanish': 1,
#          'barbarossa': 1,
#          'overlord': 1,
#          'empires': 1,
#          'web': 1,
#          '1914': 1,
#          'continent': 1,
#          'movement': 1,
#          'initially': 1,
#          'cost': 1,
#          'especially': 1,
#          'sign': 1,
#          'ethnic': 1,
#          'former': 1,
#          'called': 1,
#          'limited': 1,
#          'spread': 1,
#          'poor': 1,
#          'regime': 1,
#          'socialist': 1,
#          'economy': 1,
#          'solution': 1,
#          '1930s': 1,
#          'remained': 1,
#          'leadership': 1,
#          'little': 1,
#          'ordinary': 1,
#          'intervention': 1,
#          'needed': 1,
#          'gave': 1,
#          'rest': 1,
#          'says': 1,
#          'threat': 1,
#          'adolf': 1,
#          'worst': 1,
#          'theater': 1,
#          'declared': 1,
#          'weeks': 1,
#          'london': 1,
#          'strategy': 1,
#          'finland': 1,
#          'hoped': 1,
#          'action': 1,
#          'land': 1,
#          'considered': 1,
#          'luftwaffe': 1,
#          'core': 1,
#          'greece': 1,
#          'him': 1,
#          'losses': 1,
#          'radar': 1,
#          'impact': 1,
#          'quickly': 1,
#          'taken': 1,
#          '1941': 1,
#          'coup': 1,
#          'middle': 1,
#          'iran': 1,
#          'stalingrad': 1,
#          'way': 1,
#          'assured': 1,
#          'prisoners': 1,
#          'captured': 1,
#          'soviets': 1,
#          'ground': 1,
#          'casualties': 1,
#          'policy': 1,
#          'fight': 1,
#          'lost': 1,
#          'axis': 1,
#          'winston': 1,
#          'though': 1,
#          'controlled': 1,
#          'republic': 1,
#          'described': 1,
#          'america': 1,
#          'know': 1,
#          'propaganda': 1,
#          'bloodiest': 1,
#          'went': 1,
#          'four': 1,
#          'devastating': 1,
#          'commander': 1,
#          'suicide': 1,
#          'curtain': 1,
#          'incident': 1,
#          'manchuria': 1,
#          'manchukuo': 1,
#          'relations': 1,
#          'conflicts': 1,
#          'base': 1,
#          'before': 1,
#          'douglas': 1,
#          'australian': 1,
#          'midway': 1,
#          'attacking': 1,
#          'gulf': 1,
#          'achieved': 1,
#          'iwo': 1,
#          'jima': 1,
#          'historians': 1,
#          'okinawa': 1,
#          'center': 1,
#          'lead': 1,
#          'destruction': 1,
#          'hiroshima': 1,
#          'nagasaki': 1,
#          'borders': 1,
#          'nuremberg': 1,
#          'areas': 1,
#          'manhattan': 1,
#          'success': 1,
#          'brought': 1,
#          'rapidly': 1,
#          'israel': 1,
#          '1968': 1,
#          'crimes': 1,
#          '1949': 1,
#          'along': 1,
#          'nixon': 1,
#          'moon': 1,
#          'astronauts': 1,
#          'spacecraft': 1,
#          '1990s': 1,
#          'computing': 1,
#          'memory': 1,
#          'mark': 1,
#          'bulletin': 1,
#          'al': 1,
#          'tim': 1,
#          'geographic': 1,
#          'virus': 1,
#          'brian': 1,
#          'learning': 1,
#          'influenza': 1,
#          'pmc': 1,
#          '2005': 1,
#          '2004': 1,
#          'ago': 1,
#          'forgotten': 1,
#          'johnson': 1,
#          '2010': 1,
#          '3rd': 1,
#          '1st': 1,
#          'will': 1,
#          'hours': 1,
#          'able': 1,
#          'everything': 1,
#          'just': 1,
#          'whether': 1,
#          'support': 1,
#          'donations': 1,
#          'term': 1,
#          'stop': 1,
#          'account': 1,
#          'my': 1,
#          'order': 1,
#          'infrastructure': 1,
#          'alone': 1,
#          'enough': 1,
#          'photo': 1,
#          'photos': 1,
#          'local': 1,
#          'secure': 1,
#          'activities': 1,
#          'globe': 1,
#          'assistance': 1,
#          'costs': 1,
#          'incoming': 1,
#          'concerns': 1,
#          'public': 1,
#          'act': 1,
#          'point': 1,
#          'gain': 1,
#          'regional': 1,
#          'interests': 1,
#          'least': 1,
#          'total': 1,
#          'revenue': 1,
#          'without': 1,
#          'consider': 1,
#          'website': 1,
#          'figure': 1,
#          'running': 1,
#          'model': 1,
#          'content': 1,
#          'page': 1,
#          'tools': 1,
#          'toggle': 1,
#          'contents': 1,
#          'flu': 1,
#          'blitzkrieg': 1,
#          'tides': 1,
#          'communications': 1,
#          'sources': 1,
#          'languages': 1,
#          'bombs': 1,
#          'changes': 1,
#          '1900s': 1,
#          'decade': 1,
#          'genocide': 1,
#          'assassination': 1,
#          'member': 1,
#          'young': 1,
#          '1917': 1,
#          'unable': 1,
#          'show': 1,
#          'off': 1,
#          'machine': 1,
#          'deadly': 1,
#          'sides': 1,
#          'widely': 1,
#          'believed': 1,
#          'trench': 1,
#          'defense': 1,
#          'stage': 1,
#          'democratic': 1,
#          'kaiser': 1,
#          'map': 1,
#          'theory': 1,
#          'formed': 1,
#          'things': 1,
#          'broke': 1,
#          'deadliest': 1,
#          'high': 1,
#          'wartime': 1,
#          'trenches': 1,
#          'combined': 1,
#          'wave': 1,
#          'majority': 1,
#          'democracies': 1,
#          'industry': 1,
#          'warning': 1,
#          'crash': 1,
#          'responses': 1,
#          'millions': 1,
#          'steady': 1,
#          'welfare': 1,
#          'appeared': 1,
#          'benito': 1,
#          'ideology': 1,
#          'slave': 1,
#          'racial': 1,
#          'extermination': 1,
#          'widespread': 1,
#          'austria': 1,
#          'collapsed': 1,
#          'regimes': 1,
#          'attempted': 1,
#          '1939': 1,
#          'list': 1,
#          'alliance': 1,
#          'mobile': 1,
#          'wehrmacht': 1,
#          'lithuania': 1,
#          'possession': 1,
#          'red': 1,
#          'met': 1,
#          'resistance': 1,
#          'cause': 1,
#          'ally': 1,
#          'denmark': 1,
#          'neutrality': 1,
#          'low': 1,
#          'line': 1,
#          'border': 1,
#          'incredible': 1,
#          'marshal': 1,
#          'dunkirk': 1,
#          'hermann': 1,
#          'göring': 1,
#          'allowing': 1,
#          'men': 1,
#          'invade': 1,
#          'normandy': 1,
#          'occupy': 1,
#          'charles': 1,
#          'continue': 1,
#          'burden': 1,
#          'bombers': 1,
#          'ordered': 1,
#          'named': 1,
#          'come': 1,
#          'raf': 1,
#          'successful': 1,
#          'command': 1,
#          'decision': 1,
#          'importance': 1,
#          'spring': 1,
#          'ever': 1,
#          'seen': 1,
#          'present': 1,
#          'advanced': 1,
#          'miles': 1,
#          'capturing': 1,
#          'break': 1,
#          'reality': 1,
#          'americans': 1,
#          'parts': 1,
#          'el': 1,
#          'alamein': 1,
#          'struggling': 1,
#          'tide': 1,
#          'southern': 1,
#          'hands': 1,
#          'really': 1,
#          'italian': 1,
#          'assault': 1,
#          'landing': 1,
#          'carried': 1,
#          'late': 1,
#          'real': 1,
#          'failed': 1,
#          'failure': 1,
#          'roosevelt': 1,
#          'agreed': 1,
#          'split': 1,
#          'reports': 1,
#          'mainly': 1,
#          'committed': 1,
#          'iron': 1,
#          'event': 1,
#          'usually': 1,
#          'report': 1,
#          'left': 1,
#          'placed': 1,
#          '1937': 1,
#          'reached': 1,
#          'virginia': 1,
#          'speech': 1,
#          'colonies': 1,
#          'guam': 1,
#          'guinea': 1,
#          'aerial': 1,
#          'planning': 1,
#          'get': 1,
#          'mainland': 1,
#          'fighting': 1,
#          'leyte': 1,
#          'organized': 1,
#          'meant': 1,
#          'downfall': 1,
#          'estimated': 1,
#          'potsdam': 1,
#          'declaration': 1,
#          'threatened': 1,
#          'dropped': 1,
#          'bombings': 1,
#          'fire': 1,
#          'reich': 1,
#          'ghettos': 1,
#          'armed': 1,
#          'devised': 1,
#          'team': 1,
#          'detonated': 1,
#          'produced': 1,
#          'boy': 1,
#          'tense': 1,
#          'pakistan': 1,
#          'programs': 1,
#          'themselves': 1,
#          'economies': 1,
#          'trials': 1,
#          'trial': 1,
#          'indian': 1,
#          '1950s': 1,
#          '1946': 1,
#          'religious': 1,
#          'mutual': 1,
#          'warsaw': 1,
#          'populations': 1,
#          'must': 1,
#          'romania': 1,
#          'cuba': 1,
#          '17th': 1,
#          'vietnamese': 1,
#          'saigon': 1,
#          'kennedy': 1,
#          'sputnik': 1,
#          'milestones': 1,
#          'exploration': 1,
#          'venera': 1,
#          'wall': 1,
#          'boris': 1,
#          'mass': 1,
#          '1991': 1,
#          'invention': 1,
#          'open': 1,
#          'companies': 1,
#          'compaq': 1,
#          'released': 1,
#          'data': 1,
#          'protocol': 1,
#          'convenient': 1,
#          'scientific': 1,
#          'domination': 1,
#          'warming': 1,
#          'climate': 1,
#          '19th': 1,
#          'disease': 1,
#          'diseases': 1,
#          'epidemic': 1,
#          '1999': 1,
#          '2000': 1,
#          'infectious': 1,
#          'thoughtco': 1,
#          'life': 1,
#          'books': 1,
#          '2007': 1,
#          '1988': 1,
#          'jstor': 1,
#          'violence': 1,
#          'alan': 1,
#          'explained': 1,
#          'archive': 1,
#          'peck': 1,
#          'media': 1,
#          'pictures': 1,
#          'commission': 1,
#          '1994': 1,
#          '1998': 1,
#          '2006': 1,
#          'house': 1,
#          'historical': 1,
#          'conversation': 1,
#          ...})

# %%
text_clean = data.lower()

# %%
country_mentions = []

# %%
for country in countries:
    count = text_clean.count(country.lower())
    
    if count > 0: 
        country_mentions.append({"Country": country, "Mentions": count})

# %%
df_country_mentions = pd.DataFrame(country_mentions)

# %%
df_country_mentions
# Out:
#            Country  Mentions
# 0      Afghanistan         1
# 1          Albania         2
# 2          Algeria         1
# 3           Angola         1
# 4        Australia         6
# ..             ...       ...
# 66        Thailand         1
# 67         Ukraine         2
# 68  United Kingdom         2
# 69   United States        23
# 70         Vietnam        16
#
# [71 rows x 2 columns]

# %%
df = df_country_mentions.transpose().reset_index()

# %%
df.dtypes
# Out:
# index    object
# 0        object
# 1        object
# 2        object
# 3        object
#           ...
# 66       object
# 67       object
# 68       object
# 69       object
# 70       object
# Length: 72, dtype: object

# %%
df
# Out:
#       index            0        1        2       3          4        5  \
# 0   Country  Afghanistan  Albania  Algeria  Angola  Australia  Austria
# 1  Mentions            1        2        1       1          6        5
#
#             6        7        8  ...            61           62     63     64  \
# 0  Bangladesh  Belarus  Belgium  ...  South Africa  South Korea  Spain  Sudan
# 1           2        1        2  ...             3            3      1      1
#
#        65        66       67              68             69       70
# 0  Sweden  Thailand  Ukraine  United Kingdom  United States  Vietnam
# 1       1         1        2               2             23       16
#
# [2 rows x 72 columns]

# %%
plt.figure(figsize=(10, 15))
with sns.dark_palette("#79C", 27):
    sns.barplot(x = "Mentions", y = "Country",
    saturation=0.9, data = df_country_mentions.sort_values("Mentions", ascending = False)).set_title("20th Century Wikipedia - most frequently mentioned countries")
